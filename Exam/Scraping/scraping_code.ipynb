# %%
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import re
import os
import time

# %%
data=pd.read_pickle('missings18.pkl')
data1=data[0:1000]
data2=data[1121:]
#data1=data[0:200] # FÆRDIG
#data2=data[200:1000]      # CHRISTIAN
#data3=data[1000:2000]     # CHRISTIAN
#data4=data[2000:3000]
#data5=data[3000:4000]     # THOR
#data6=data[4000:]         # MORTEN

# %%
def skyscannerscraper(dep,arr,date, save, driverpath, direct='true'):
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # save: filename
    # driverpath: complete path to driver
    # direct: indicates whether direct flight is preferred
    save2=save+".pkl"
    
    driver = webdriver.Firefox(executable_path=driverpath)
    driver.implicitly_wait(7)
    wait = WebDriverWait(driver, 8)
    urlbase = 'https://www.skyscanner.com/transport/flights/'
    urlpas='/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    data = []
    count=0
    for depa,arri in zip(dep,arr):
        count+=1
        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend

        driver.get(url)
        time.sleep(6) 
        try:
            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
            r=price[0]
            if r==' ':
                del r
                #print('r=0')
                raise ValueError
            elif r=='Ingen':
                #print('r=0')
                raise ValueError
                del r
            else:
                data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                del r
                del price
            
        except (TimeoutException,StaleElementReferenceException,BaseException):
            try:
                WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
                #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                r=price[0]
                if r==' ':
                    del r
                    #print('r=0')
                    raise ValueError
                elif r=='Ingen':
                    del r
                    #print('r=0')
                    raise ValueError
                else:
                    data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                    del r
                    del price
                    


            except (TimeoutException,StaleElementReferenceException,BaseException):
                try:
                    time.sleep(3)
                    #print('Round2')
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                    #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                    label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                    r=price[0]
                    if r==' ':
                        del r
                        #print('r=0')
                        raise ValueError
                    elif r=='Ingen':
                        #print('r=0')
                        raise ValueError
                        del r
                    else:
                        data.append({
                            "price": price[0],
                            "origin": str(depa),
                            "destination": str(arri),
                            "label": label[0],
                            "day":0
                                })
                        del r
                        del price

                except (TimeoutException,StaleElementReferenceException,BaseException):
                        try:
                            WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                            wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                            r=price[0]
                            if r==' ':
                                del r
                                #print('r=0')
                                raise ValueError
                            elif r=='Ingen':
                                del r
                                #print('r=0')
                                raise ValueError
                            else:
                                data.append({
                                "price": price[0],
                                "origin": str(depa),
                                "destination": str(arri),
                                "label": label[0],
                                "day":0
                                    })
                                del r
                                del price

                        except (TimeoutException,StaleElementReferenceException,BaseException):
                            try:
                                #print('indirect')
                                wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))

                                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                                data.append({
                                        "price": price[1],
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": label[1],
                                        "day":0,
                                        "alternative": price[0]
                                            })
                                del price


                            except (TimeoutException,StaleElementReferenceException,BaseException):

                                print("Not working for "+str(url))


                                data.append({
                                        "price": '-',
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": '-',
                                        "day":0
                                            })
                    
        print(str(depa)+"-"+str(arri))
        
        print(str(count)+" af " +str(len(dep.index)))
        time.sleep(2)
        price_data = pd.DataFrame(data)
        if count%20==0:
            price_data.to_pickle(save2)
        if count%200==0:
            time.sleep(300)

    price_data.to_pickle(save2)

    driver.close()
        
    return price_data

# %% [markdown]
# ### CHRISTIAN

# %%
# Indsæt driverpath (skal vise lokal path)
prices2=skyscannerscraper(data1['Origin'],data1['Dest'],190527,save="missings_190528", driverpath='/Users/Christian/Dropbox/Universitet/TSODAS/TSDS-gruppe-2019/Exam/geckodriver', direct='false')
# Out:
# Not working for https://www.skyscanner.com/transport/flights/OGG/ORD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OGG-ORD
# 1 af 1000
# IAD-HNL
# 2 af 1000
# HNL-IAD
# 3 af 1000
# Not working for https://www.skyscanner.com/transport/flights/EWR/JAC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# EWR-JAC
# 4 af 1000
# Not working for https://www.skyscanner.com/transport/flights/ORD/OGG/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORD-OGG
# 5 af 1000
# HNL-GUM
# 6 af 1000
# GUM-HNL
# 7 af 1000
# JAC-EWR
# 8 af 1000
# TPA-SFO
# 9 af 1000
# SFO-DCA
# 10 af 1000
# DCA-SFO
# 11 af 1000
# RDU-SFO
# 12 af 1000
# BNA-SFO
# 13 af 1000
# SFO-BNA
# 14 af 1000
# ITO-LAX
# 15 af 1000
# SFO-RDU
# 16 af 1000
# SFO-FLL
# 17 af 1000
# LAX-ITO
# 18 af 1000
# FLL-SFO
# 19 af 1000
# SFO-TPA
# 20 af 1000
# SMF-EWR
# 21 af 1000
# RIC-DEN
# 22 af 1000
# EWR-SMF
# 23 af 1000
# DEN-RIC
# 24 af 1000
# ORD-SRQ
# 25 af 1000
# SRQ-ORD
# 26 af 1000
# EWR-BZN
# 27 af 1000
# BZN-EWR
# 28 af 1000
# GUC-IAH
# 29 af 1000
# IAH-GUC
# 30 af 1000
# FLL-SEA
# 31 af 1000
# SEA-FLL
# 32 af 1000
# SEA-BLI
# 33 af 1000
# SEA-SBA
# 34 af 1000
# SBA-SEA
# 35 af 1000
# SEA-SAT
# 36 af 1000
# TPA-SEA
# 37 af 1000
# SAT-SEA
# 38 af 1000
# SEA-OMA
# 39 af 1000
# SEA-CHS
# 40 af 1000
# RDU-SEA
# 41 af 1000
# SEA-RDU
# 42 af 1000
# PDX-AUS
# 43 af 1000
# OMA-SEA
# 44 af 1000
# PDX-DCA
# 45 af 1000
# SEA-TPA
# 46 af 1000
# DCA-PDX
# 47 af 1000
# CHS-SEA
# 48 af 1000
# AUS-PDX
# 49 af 1000
# SJC-OGG
# 50 af 1000
# OGG-BLI
# 51 af 1000
# OGG-SJC
# 52 af 1000
# SJC-KOA
# 53 af 1000
# PDX-LIH
# 54 af 1000
# SEA-KOA
# 55 af 1000
# LIH-SJC
# 56 af 1000
# KOA-PDX
# 57 af 1000
# PDX-KOA
# 58 af 1000
# LIH-SAN
# 59 af 1000
# OAK-LIH
# 60 af 1000
# BLI-OGG
# 61 af 1000
# LIH-PDX
# 62 af 1000
# KOA-SJC
# 63 af 1000
# SAN-LIH
# 64 af 1000
# SJC-LIH
# 65 af 1000
# LIH-OAK
# 66 af 1000
# Not working for https://www.skyscanner.com/transport/flights/ADK/ANC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ADK-ANC
# 67 af 1000
# Not working for https://www.skyscanner.com/transport/flights/ANC/ADK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ANC-ADK
# 68 af 1000
# Not working for https://www.skyscanner.com/transport/flights/KOA/SAN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# KOA-SAN
# 69 af 1000
# OGG-ANC
# 70 af 1000
# Not working for https://www.skyscanner.com/transport/flights/SAN/KOA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SAN-KOA
# 71 af 1000
# KOA-ANC
# 72 af 1000
# BTV-LGA
# 73 af 1000
# LGA-BUF
# 74 af 1000
# MKE-LGA
# 75 af 1000
# MCI-LGA
# 76 af 1000
# ORF-LGA
# 77 af 1000
# BUF-LGA
# 78 af 1000
# LGA-ORF
# 79 af 1000
# LGA-MHT
# 80 af 1000
# FLL-RDU
# 81 af 1000
# RDU-FLL
# 82 af 1000
# SYR-LGA
# 83 af 1000
# CHS-JFK
# 84 af 1000
# LGA-MKE
# 85 af 1000
# ROC-LGA
# 86 af 1000
# LGA-SYR
# 87 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MHT/LGA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MHT-LGA
# 88 af 1000
# CHA-DTW
# 89 af 1000
# LGA-ROC
# 90 af 1000
# LGA-MCI
# 91 af 1000
# DAY-LGA
# 92 af 1000
# LGA-BTV
# 93 af 1000
# LGA-CHO
# 94 af 1000
# BGR-JFK
# 95 af 1000
# DTW-CHA
# 96 af 1000
# LGA-SRQ
# 97 af 1000
# JFK-BGR
# 98 af 1000
# JFK-CHS
# 99 af 1000
# SAV-JFK
# 100 af 1000
# BOS-MKE
# 101 af 1000
# CHO-LGA
# 102 af 1000
# BOS-MCI
# 103 af 1000
# LGA-DAY
# 104 af 1000
# OMA-LGA
# 105 af 1000
# MCI-BOS
# 106 af 1000
# HRL-MSP
# 107 af 1000
# MSP-HRL
# 108 af 1000
# MKE-BOS
# 109 af 1000
# MSP-LEX
# 110 af 1000
# SRQ-LGA
# 111 af 1000
# JFK-ABQ
# 112 af 1000
# ABQ-JFK
# 113 af 1000
# RNO-JFK
# 114 af 1000
# JFK-RNO
# 115 af 1000
# ALB-FLL
# 116 af 1000
# FLL-ALB
# 117 af 1000
# CHS-DCA
# 118 af 1000
# JFK-PSP
# 119 af 1000
# PSP-JFK
# 120 af 1000
# SJU-STX
# 121 af 1000
# STX-SJU
# 122 af 1000
# JFK-DAB
# 123 af 1000
# BUF-LAX
# 124 af 1000
# LAX-BUF
# 125 af 1000
# DAB-JFK
# 126 af 1000
# FLL-AUS
# 127 af 1000
# AUS-FLL
# 128 af 1000
# FLL-SAN
# 129 af 1000
# SAN-FLL
# 130 af 1000
# MCO-PSE
# 131 af 1000
# PSE-MCO
# 132 af 1000
# LGB-SJC
# 133 af 1000
# SFO-LGB
# 134 af 1000
# LGB-SFO
# 135 af 1000
# Not working for https://www.skyscanner.com/transport/flights/JFK/PSE/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# JFK-PSE
# 136 af 1000
# SJC-LGB
# 137 af 1000
# JFK-BQN
# 138 af 1000
# DCA-CHS
# 139 af 1000
# HOU-BOS
# 140 af 1000
# BOS-HOU
# 141 af 1000
# FLL-BQN
# 142 af 1000
# BQN-FLL
# 143 af 1000
# PDX-LGB
# 144 af 1000
# FLL-CHS
# 145 af 1000
# DCA-SJU
# 146 af 1000
# SJU-DCA
# 147 af 1000
# LGB-AUS
# 148 af 1000
# AUS-LGB
# 149 af 1000
# LGB-PDX
# 150 af 1000
# ORH-MCO
# 151 af 1000
# MCO-ORH
# 152 af 1000
# ORH-FLL
# 153 af 1000
# FLL-ORH
# 154 af 1000
# CHS-FLL
# 155 af 1000
# SYR-BOS
# 156 af 1000
# BOS-SYR
# 157 af 1000
# BTR-CLT
# 158 af 1000
# DFW-MHK
# 159 af 1000
# MHK-DFW
# 160 af 1000
# CLT-TYS
# 161 af 1000
# TYS-CLT
# 162 af 1000
# CLT-BTR
# 163 af 1000
# DFW-SAF
# 164 af 1000
# SAF-DFW
# 165 af 1000
# COU-DFW
# 166 af 1000
# DFW-COU
# 167 af 1000
# CHA-EWR
# 168 af 1000
# AVP-EWR
# 169 af 1000
# EWR-AVP
# 170 af 1000
# EWR-SBN
# 171 af 1000
# IAH-SGF
# 172 af 1000
# ECP-IAH
# 173 af 1000
# IAH-ECP
# 174 af 1000
# EWR-CAK
# 175 af 1000
# CAK-EWR
# 176 af 1000
# HOB-IAH
# 177 af 1000
# EWR-CHA
# 178 af 1000
# ATL-RST
# 179 af 1000
# LGA-OMA
# 180 af 1000
# ATL-LNK
# 181 af 1000
# ATL-ECP
# 182 af 1000
# ECP-ATL
# 183 af 1000
# Not working for https://www.skyscanner.com/transport/flights/LNK/ATL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LNK-ATL
# 184 af 1000
# RST-ATL
# 185 af 1000
# SGF-IAH
# 186 af 1000
# SBN-EWR
# 187 af 1000
# EWR-FWA
# 188 af 1000
# EWR-DSM
# 189 af 1000
# IAH-HOB
# 190 af 1000
# FWA-EWR
# 191 af 1000
# DSM-EWR
# 192 af 1000
# Not working for https://www.skyscanner.com/transport/flights/LEX/MSP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LEX-MSP
# 193 af 1000
# Not working for https://www.skyscanner.com/transport/flights/RSW/TTN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RSW-TTN
# 194 af 1000
# ISP-MIA
# 195 af 1000
# TTN-MCO
# 196 af 1000
# MCO-COS
# 197 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MCO/OKC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCO-OKC
# 198 af 1000
# MKE-MIA
# 199 af 1000
# MIA-PVD
# 200 af 1000
# Not working for https://www.skyscanner.com/transport/flights/OMA/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-MCO
# 201 af 1000
# Not working for https://www.skyscanner.com/transport/flights/RSW/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RSW-BNA
# 202 af 1000
# Not working for https://www.skyscanner.com/transport/flights/BNA/RSW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BNA-RSW
# 203 af 1000
# Not working for https://www.skyscanner.com/transport/flights/COS/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# COS-TPA
# 204 af 1000
# MCO-TTN
# 205 af 1000
# Not working for https://www.skyscanner.com/transport/flights/PVD/RSW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-RSW
# 206 af 1000
# Not working for https://www.skyscanner.com/transport/flights/OKC/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-MCO
# 207 af 1000
# Not working for https://www.skyscanner.com/transport/flights/RSW/MKE/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RSW-MKE
# 208 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MCO/OMA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCO-OMA
# 209 af 1000
# Not working for https://www.skyscanner.com/transport/flights/TTN/PBI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# TTN-PBI
# 210 af 1000
# PVD-MIA
# 211 af 1000
# TPA-COS
# 212 af 1000
# Not working for https://www.skyscanner.com/transport/flights/RSW/PVD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RSW-PVD
# 213 af 1000
# Not working for https://www.skyscanner.com/transport/flights/TTN/RSW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# TTN-RSW
# 214 af 1000
# Not working for https://www.skyscanner.com/transport/flights/COS/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# COS-MCO
# 215 af 1000
# MIA-MKE
# 216 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MKE/RSW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MKE-RSW
# 217 af 1000
# MIA-ISP
# 218 af 1000
# Not working for https://www.skyscanner.com/transport/flights/PBI/TTN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-TTN
# 219 af 1000
# MCO-DSM
# 220 af 1000
# RSW-BUF
# 221 af 1000
# CLT-TTN
# 222 af 1000
# RSW-GRR
# 223 af 1000
# TTN-CLT
# 224 af 1000
# Not working for https://www.skyscanner.com/transport/flights/LAS/MSN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LAS-MSN
# 225 af 1000
# MSN-MCO
# 226 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MCI/RSW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCI-RSW
# 227 af 1000
# TTN-TPA
# 228 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MSN/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSN-LAS
# 229 af 1000
# DSM-MCO
# 230 af 1000
# GRR-RSW
# 231 af 1000
# MCO-MSN
# 232 af 1000
# TPA-TTN
# 233 af 1000
# Not working for https://www.skyscanner.com/transport/flights/RSW/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RSW-MCI
# 234 af 1000
# BUF-RSW
# 235 af 1000
# MIA-BUF
# 236 af 1000
# BUF-MIA
# 237 af 1000
# FLL-GSP
# 238 af 1000
# GSP-FLL
# 239 af 1000
# FLL-ORF
# 240 af 1000
# ORF-FLL
# 241 af 1000
# SFB-TYS
# 242 af 1000
# TYS-SFB
# 243 af 1000
# PIE-DAY
# 244 af 1000
# DAY-PIE
# 245 af 1000
# PIE-DSM
# 246 af 1000
# DSM-PIE
# 247 af 1000
# PIE-FWA
# 248 af 1000
# FWA-PIE
# 249 af 1000
# PIE-IAG
# 250 af 1000
# IAG-PIE
# 251 af 1000
# PIE-BLV
# 252 af 1000
# BLV-PIE
# 253 af 1000
# PIE-TYS
# 254 af 1000
# TYS-PIE
# 255 af 1000
# PIE-PVD
# 256 af 1000
# PVD-PIE
# 257 af 1000
# PIE-SYR
# 258 af 1000
# SYR-PIE
# 259 af 1000
# PIE-TOL
# 260 af 1000
# TOL-PIE
# 261 af 1000
# PIE-MDT
# 262 af 1000
# MDT-PIE
# 263 af 1000
# PIE-IND
# 264 af 1000
# IND-PIE
# 265 af 1000
# PIE-BGR
# 266 af 1000
# BGR-PIE
# 267 af 1000
# SFB-HGR
# 268 af 1000
# HGR-SFB
# 269 af 1000
# SFB-IAG
# 270 af 1000
# IAG-SFB
# 271 af 1000
# AVL-PIE
# 272 af 1000
# PIE-ROA
# 273 af 1000
# ROA-PIE
# 274 af 1000
# PIE-GRR
# 275 af 1000
# GRR-PIE
# 276 af 1000
# PIE-CID
# 277 af 1000
# CID-PIE
# 278 af 1000
# PIE-RFD
# 279 af 1000
# RFD-PIE
# 280 af 1000
# PIE-SBN
# 281 af 1000
# SBN-PIE
# 282 af 1000
# PIE-PBG
# 283 af 1000
# PBG-PIE
# 284 af 1000
# PIE-PIA
# 285 af 1000
# PIA-PIE
# 286 af 1000
# PIE-AVL
# 287 af 1000
# AVL-SFB
# 288 af 1000
# SFB-AVL
# 289 af 1000
# SFB-OWB
# 290 af 1000
# OWB-SFB
# 291 af 1000
# SFB-PBG
# 292 af 1000
# PBG-SFB
# 293 af 1000
# PIE-GSP
# 294 af 1000
# GSP-PIE
# 295 af 1000
# PIE-HTS
# 296 af 1000
# HTS-PIE
# 297 af 1000
# PIE-SGF
# 298 af 1000
# SGF-PIE
# 299 af 1000
# PIE-BMI
# 300 af 1000
# BMI-PIE
# 301 af 1000
# AVL-FLL
# 302 af 1000
# FLL-AVL
# 303 af 1000
# FLL-PBG
# 304 af 1000
# Not working for https://www.skyscanner.com/transport/flights/PBG/FLL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBG-FLL
# 305 af 1000
# PGD-RDU
# 306 af 1000
# RDU-PGD
# 307 af 1000
# PGD-TYS
# 308 af 1000
# TYS-PGD
# 309 af 1000
# PGD-ABE
# 310 af 1000
# ABE-PGD
# 311 af 1000
# PGD-USA
# 312 af 1000
# USA-PGD
# 313 af 1000
# PGD-GRR
# 314 af 1000
# Not working for https://www.skyscanner.com/transport/flights/GRR/PGD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# GRR-PGD
# 315 af 1000
# PGD-AVL
# 316 af 1000
# AVL-PGD
# 317 af 1000
# PGD-MCI
# 318 af 1000
# MCI-PGD
# 319 af 1000
# PGD-PIA
# 320 af 1000
# PIA-PGD
# 321 af 1000
# SFB-FSD
# 322 af 1000
# FSD-SFB
# 323 af 1000
# SFB-GRR
# 324 af 1000
# GRR-SFB
# 325 af 1000
# PGD-IND
# 326 af 1000
# IND-PGD
# 327 af 1000
# PGD-LEX
# 328 af 1000
# LEX-PGD
# 329 af 1000
# PGD-CID
# 330 af 1000
# CID-PGD
# 331 af 1000
# PGD-LCK
# 332 af 1000
# LCK-PGD
# 333 af 1000
# SFB-ABE
# 334 af 1000
# ABE-SFB
# 335 af 1000
# SFB-LEX
# 336 af 1000
# LEX-SFB
# 337 af 1000
# PGD-IAG
# 338 af 1000
# IAG-PGD
# 339 af 1000
# PGD-DAY
# 340 af 1000
# DAY-PGD
# 341 af 1000
# PGD-SWF
# 342 af 1000
# SWF-PGD
# 343 af 1000
# PGD-MLI
# 344 af 1000
# MLI-PGD
# 345 af 1000
# SFB-CID
# 346 af 1000
# CID-SFB
# 347 af 1000
# SFB-FNT
# 348 af 1000
# FNT-SFB
# 349 af 1000
# LAS-BZN
# 350 af 1000
# BZN-LAS
# 351 af 1000
# LAX-MFR
# 352 af 1000
# MFR-LAX
# 353 af 1000
# AZA-GRI
# 354 af 1000
# GRI-AZA
# 355 af 1000
# AZA-ICT
# 356 af 1000
# ICT-AZA
# 357 af 1000
# BLI-LAS
# 358 af 1000
# LAS-BLI
# 359 af 1000
# AZA-BIS
# 360 af 1000
# BIS-AZA
# 361 af 1000
# Not working for https://www.skyscanner.com/transport/flights/ABQ/AUS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ABQ-AUS
# 362 af 1000
# Not working for https://www.skyscanner.com/transport/flights/AUS/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# AUS-ABQ
# 363 af 1000
# LAS-FCA
# 364 af 1000
# FCA-LAS
# 365 af 1000
# AZA-SBN
# 366 af 1000
# SBN-AZA
# 367 af 1000
# AZA-RAP
# 368 af 1000
# RAP-AZA
# 369 af 1000
# AZA-OGD
# 370 af 1000
# OGD-AZA
# 371 af 1000
# AZA-RFD
# 372 af 1000
# RFD-AZA
# 373 af 1000
# CVG-PIE
# 374 af 1000
# PIE-CVG
# 375 af 1000
# PIT-AUS
# 376 af 1000
# AUS-PIT
# 377 af 1000
# PIT-PIE
# 378 af 1000
# PIE-PIT
# 379 af 1000
# FSD-AZA
# 380 af 1000
# AZA-PVU
# 381 af 1000
# PVU-AZA
# 382 af 1000
# OAK-BLI
# 383 af 1000
# BLI-OAK
# 384 af 1000
# CVG-SFB
# 385 af 1000
# SFB-CVG
# 386 af 1000
# BLI-PSP
# 387 af 1000
# PSP-BLI
# 388 af 1000
# AZA-BLV
# 389 af 1000
# BLV-AZA
# 390 af 1000
# CVG-PGD
# 391 af 1000
# PGD-CVG
# 392 af 1000
# AZA-CVG
# 393 af 1000
# CVG-AZA
# 394 af 1000
# AZA-DSM
# 395 af 1000
# AZA-DSM
# 396 af 1000
# DSM-AZA
# 397 af 1000
# DSM-AZA
# 398 af 1000
# AZA-BZN
# 399 af 1000
# BZN-AZA
# 400 af 1000
# AZA-BOI
# 401 af 1000
# BOI-AZA
# 402 af 1000
# LAS-SBN
# 403 af 1000
# LAS-GRI
# 404 af 1000
# GRI-LAS
# 405 af 1000
# SFB-HTS
# 406 af 1000
# HTS-SFB
# 407 af 1000
# SBN-SFB
# 408 af 1000
# SFB-SGF
# 409 af 1000
# SGF-SFB
# 410 af 1000
# SFB-TOL
# 411 af 1000
# TOL-SFB
# 412 af 1000
# LAS-GFK
# 413 af 1000
# GFK-LAS
# 414 af 1000
# LAS-XNA
# 415 af 1000
# XNA-LAS
# 416 af 1000
# LAS-RFD
# 417 af 1000
# RFD-LAS
# 418 af 1000
# LAS-BIS
# 419 af 1000
# BIS-LAS
# 420 af 1000
# LAS-FAR
# 421 af 1000
# FAR-LAS
# 422 af 1000
# LAS-RAP
# 423 af 1000
# RAP-LAS
# 424 af 1000
# LAS-FSD
# 425 af 1000
# FSD-LAS
# 426 af 1000
# LAS-MFE
# 427 af 1000
# MFE-LAS
# 428 af 1000
# LAS-BLV
# 429 af 1000
# BLV-LAS
# 430 af 1000
# LAS-SCK
# 431 af 1000
# SCK-LAS
# 432 af 1000
# SFB-TUL
# 433 af 1000
# TUL-SFB
# 434 af 1000
# LAS-MOT
# 435 af 1000
# MOT-LAS
# 436 af 1000
# LAS-ATW
# 437 af 1000
# ATW-LAS
# 438 af 1000
# LAS-ICT
# 439 af 1000
# ICT-LAS
# 440 af 1000
# SFB-SBN
# 441 af 1000
# SBN-LAS
# 442 af 1000
# SFB-ROA
# 443 af 1000
# ROA-SFB
# 444 af 1000
# OAK-EUG
# 445 af 1000
# EUG-OAK
# 446 af 1000
# LAS-DSM
# 447 af 1000
# DSM-LAS
# 448 af 1000
# LAS-GJT
# 449 af 1000
# GJT-LAS
# 450 af 1000
# LAS-SMX
# 451 af 1000
# SMX-LAS
# 452 af 1000
# FLL-USA
# 453 af 1000
# USA-FLL
# 454 af 1000
# SFB-RDU
# 455 af 1000
# RDU-SFB
# 456 af 1000
# SFB-TRI
# 457 af 1000
# TRI-SFB
# 458 af 1000
# PIE-USA
# 459 af 1000
# USA-PIE
# 460 af 1000
# PIE-RIC
# 461 af 1000
# RIC-PIE
# 462 af 1000
# PIE-GSO
# 463 af 1000
# GSO-PIE
# 464 af 1000
# PIT-JAX
# 465 af 1000
# JAX-PIT
# 466 af 1000
# PIE-SDF
# 467 af 1000
# SDF-PIE
# 468 af 1000
# PIE-AUS
# 469 af 1000
# CLE-PIE
# 470 af 1000
# PIE-FNT
# 471 af 1000
# PIE-CLE
# 472 af 1000
# AUS-PIE
# 473 af 1000
# SFB-SJU
# 474 af 1000
# SJU-SFB
# 475 af 1000
# FLL-BLV
# 476 af 1000
# BLV-FLL
# 477 af 1000
# Not working for https://www.skyscanner.com/transport/flights/FLL/MKE/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# FLL-MKE
# 478 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MKE/FLL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MKE-FLL
# 479 af 1000
# PIE-ABE
# 480 af 1000
# ABE-PIE
# 481 af 1000
# PIE-CHA
# 482 af 1000
# CHA-SFB
# 483 af 1000
# SFB-CHA
# 484 af 1000
# CHA-PIE
# 485 af 1000
# PIE-LCK
# 486 af 1000
# LCK-PIE
# 487 af 1000
# PIE-LEX
# 488 af 1000
# LEX-PIE
# 489 af 1000
# AVL-BWI
# 490 af 1000
# BWI-AVL
# 491 af 1000
# FLL-LEX
# 492 af 1000
# LEX-FLL
# 493 af 1000
# PIE-MKE
# 494 af 1000
# MKE-PIE
# 495 af 1000
# FLL-SDF
# 496 af 1000
# SDF-FLL
# 497 af 1000
# PGD-SBN
# 498 af 1000
# SBN-PGD
# 499 af 1000
# PGD-FWA
# 500 af 1000
# FWA-PGD
# 501 af 1000
# PGD-FNT
# 502 af 1000
# FNT-PGD
# 503 af 1000
# PGD-PVD
# 504 af 1000
# PVD-PGD
# 505 af 1000
# SFB-USA
# 506 af 1000
# USA-MSY
# 507 af 1000
# MSY-USA
# 508 af 1000
# USA-SFB
# 509 af 1000
# PGD-RFD
# 510 af 1000
# RFD-PGD
# 511 af 1000
# PGD-DSM
# 512 af 1000
# DSM-PGD
# 513 af 1000
# SFB-ATW
# 514 af 1000
# ATW-SFB
# 515 af 1000
# SFB-BGR
# 516 af 1000
# BGR-SFB
# 517 af 1000
# TYS-FLL
# 518 af 1000
# FLL-TYS
# 519 af 1000
# SFB-AUS
# 520 af 1000
# Not working for https://www.skyscanner.com/transport/flights/AUS/IND/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# AUS-IND
# 521 af 1000
# IND-SFB
# 522 af 1000
# SFB-LCK
# 523 af 1000
# LCK-SFB
# 524 af 1000
# LAX-TUL
# 525 af 1000
# TUL-LAX
# 526 af 1000
# AZA-FSD
# 527 af 1000
# AZA-GRR
# 528 af 1000
# GRR-AZA
# 529 af 1000
# BLI-AZA
# 530 af 1000
# AZA-BLI
# 531 af 1000
# AZA-MSO
# 532 af 1000
# MSO-AZA
# 533 af 1000
# AZA-SGF
# 534 af 1000
# SGF-AZA
# 535 af 1000
# LAS-PSC
# 536 af 1000
# PSC-LAS
# 537 af 1000
# AZA-PSC
# 538 af 1000
# PSC-AZA
# 539 af 1000
# Not working for https://www.skyscanner.com/transport/flights/AZA/MOT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# AZA-MOT
# 540 af 1000
# MOT-AZA
# 541 af 1000
# AZA-IDA
# 542 af 1000
# Not working for https://www.skyscanner.com/transport/flights/IDA/AZA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# IDA-AZA
# 543 af 1000
# AZA-EUG
# 544 af 1000
# EUG-AZA
# 545 af 1000
# Not working for https://www.skyscanner.com/transport/flights/CVG/JAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CVG-JAX
# 546 af 1000
# JAX-BLV
# 547 af 1000
# BLV-JAX
# 548 af 1000
# Not working for https://www.skyscanner.com/transport/flights/JAX/CVG/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# JAX-CVG
# 549 af 1000
# PIT-PGD
# 550 af 1000
# PGD-PIT
# 551 af 1000
# Not working for https://www.skyscanner.com/transport/flights/PIT/MSY/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIT-MSY
# 552 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MSY/PIT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-PIT
# 553 af 1000
# AZA-PIA
# 554 af 1000
# Not working for https://www.skyscanner.com/transport/flights/PIA/AZA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIA-AZA
# 555 af 1000
# LAS-IDA
# 556 af 1000
# Not working for https://www.skyscanner.com/transport/flights/IDA/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# IDA-LAS
# 557 af 1000
# VPS-BLV
# 558 af 1000
# BLV-VPS
# 559 af 1000
# BLI-SAN
# 560 af 1000
# SAN-BLI
# 561 af 1000
# BLI-LAX
# 562 af 1000
# LAX-BLI
# 563 af 1000
# AZA-GTF
# 564 af 1000
# GTF-AZA
# 565 af 1000
# LAX-PVU
# 566 af 1000
# PVU-LAX
# 567 af 1000
# AZA-CID
# 568 af 1000
# Not working for https://www.skyscanner.com/transport/flights/CID/AZA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CID-AZA
# 569 af 1000
# AZA-FAR
# 570 af 1000
# FAR-AZA
# 571 af 1000
# AZA-BIL
# 572 af 1000
# BIL-AZA
# 573 af 1000
# SFB-MCI
# 574 af 1000
# MCI-SFB
# 575 af 1000
# SFB-BMI
# 576 af 1000
# BMI-SFB
# 577 af 1000
# SFB-IND
# 578 af 1000
# Not working for https://www.skyscanner.com/transport/flights/IND/AUS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# IND-AUS
# 579 af 1000
# AUS-SFB
# 580 af 1000
# SFB-ELM
# 581 af 1000
# ELM-SFB
# 582 af 1000
# SFB-FWA
# 583 af 1000
# FWA-SFB
# 584 af 1000
# FNT-PIE
# 585 af 1000
# SFB-SAT
# 586 af 1000
# SAT-SFB
# 587 af 1000
# SFB-PSM
# 588 af 1000
# PSM-SFB
# 589 af 1000
# SFB-MDT
# 590 af 1000
# MDT-SFB
# 591 af 1000
# SFB-MEM
# 592 af 1000
# MEM-SFB
# 593 af 1000
# SFB-MFE
# 594 af 1000
# MFE-SFB
# 595 af 1000
# SFB-CKB
# 596 af 1000
# CKB-SFB
# 597 af 1000
# SFB-LIT
# 598 af 1000
# LIT-SFB
# 599 af 1000
# SFB-BLV
# 600 af 1000
# BLV-SFB
# 601 af 1000
# SFB-DSM
# 602 af 1000
# DSM-SFB
# 603 af 1000
# GRR-LAS
# 604 af 1000
# LAS-GRR
# 605 af 1000
# LAS-SGF
# 606 af 1000
# SGF-LAS
# 607 af 1000
# SFB-PIT
# 608 af 1000
# PIT-SFB
# 609 af 1000
# SFB-GSP
# 610 af 1000
# GSP-SFB
# 611 af 1000
# LAS-TYS
# 612 af 1000
# TYS-LAS
# 613 af 1000
# LAS-GTF
# 614 af 1000
# GTF-LAS
# 615 af 1000
# LAS-MSO
# 616 af 1000
# MSO-LAS
# 617 af 1000
# SFB-OMA
# 618 af 1000
# OMA-SFB
# 619 af 1000
# SFB-RFD
# 620 af 1000
# RFD-SFB
# 621 af 1000
# SFB-ORF
# 622 af 1000
# ORF-SFB
# 623 af 1000
# SFB-XNA
# 624 af 1000
# XNA-SFB
# 625 af 1000
# LAS-CID
# 626 af 1000
# CID-LAS
# 627 af 1000
# SFB-MLI
# 628 af 1000
# MLI-SFB
# 629 af 1000
# LAS-PIA
# 630 af 1000
# PIA-LAS
# 631 af 1000
# LAS-SHV
# 632 af 1000
# SHV-LAS
# 633 af 1000
# LAS-BIL
# 634 af 1000
# BIL-LAS
# 635 af 1000
# LAS-LRD
# 636 af 1000
# LRD-LAS
# 637 af 1000
# PIE-FSD
# 638 af 1000
# PIE-ELM
# 639 af 1000
# FSD-PIE
# 640 af 1000
# ELM-PIE
# 641 af 1000
# SFB-OGS
# 642 af 1000
# OGS-SFB
# 643 af 1000
# SFB-PIA
# 644 af 1000
# PIA-SFB
# 645 af 1000
# PIE-MLI
# 646 af 1000
# MLI-PIE
# 647 af 1000
# PIE-OMA
# 648 af 1000
# OMA-PIE
# 649 af 1000
# PIE-ATW
# 650 af 1000
# ATW-PIE
# 651 af 1000
# FLL-ABE
# 652 af 1000
# ABE-FLL
# 653 af 1000
# PGD-SPI
# 654 af 1000
# SPI-PGD
# 655 af 1000
# PGD-TOL
# 656 af 1000
# TOL-PGD
# 657 af 1000
# AZA-LAS
# 658 af 1000
# LAS-AZA
# 659 af 1000
# LAX-SGF
# 660 af 1000
# SGF-LAX
# 661 af 1000
# AZA-OAK
# 662 af 1000
# AZA-STC
# 663 af 1000
# STC-AZA
# 664 af 1000
# AZA-FWA
# 665 af 1000
# FWA-AZA
# 666 af 1000
# OAK-AZA
# 667 af 1000
# AZA-ATW
# 668 af 1000
# ATW-AZA
# 669 af 1000
# AZA-GFK
# 670 af 1000
# GFK-AZA
# 671 af 1000
# AZA-MLI
# 672 af 1000
# MLI-AZA
# 673 af 1000
# AZA-OMA
# 674 af 1000
# OMA-AZA
# 675 af 1000
# SFB-BIS
# 676 af 1000
# BIS-SFB
# 677 af 1000
# SFB-GPT
# 678 af 1000
# GPT-SFB
# 679 af 1000
# PIE-ORF
# 680 af 1000
# SWF-PIE
# 681 af 1000
# ORF-PIE
# 682 af 1000
# SWF-SFB
# 683 af 1000
# SFB-SWF
# 684 af 1000
# PIE-SWF
# 685 af 1000
# SFB-SDF
# 686 af 1000
# SDF-SFB
# 687 af 1000
# PSM-PGD
# 688 af 1000
# PGD-PSM
# 689 af 1000
# PGD-SDF
# 690 af 1000
# SDF-PGD
# 691 af 1000
# PIE-MCI
# 692 af 1000
# MCI-PIE
# 693 af 1000
# PIE-OGS
# 694 af 1000
# OGS-PIE
# 695 af 1000
# PIE-MEM
# 696 af 1000
# MEM-PIE
# 697 af 1000
# FLL-LCK
# 698 af 1000
# LCK-FLL
# 699 af 1000
# PGD-CLE
# 700 af 1000
# CLE-PGD
# 701 af 1000
# SFB-GSO
# 702 af 1000
# GSO-SFB
# 703 af 1000
# SFB-RIC
# 704 af 1000
# RIC-SFB
# 705 af 1000
# PGD-MDT
# 706 af 1000
# MDT-PGD
# 707 af 1000
# PGD-BLV
# 708 af 1000
# BLV-PGD
# 709 af 1000
# PGD-MKE
# 710 af 1000
# MKE-PGD
# 711 af 1000
# PIE-RDU
# 712 af 1000
# RDU-PIE
# 713 af 1000
# AZA-SCK
# 714 af 1000
# SCK-AZA
# 715 af 1000
# SFB-DAY
# 716 af 1000
# DAY-SFB
# 717 af 1000
# SFB-CLE
# 718 af 1000
# CLE-SFB
# 719 af 1000
# SFB-FAR
# 720 af 1000
# FAR-SFB
# 721 af 1000
# SFB-ROC
# 722 af 1000
# ROC-SFB
# 723 af 1000
# SFB-EVV
# 724 af 1000
# EVV-SFB
# 725 af 1000
# SFB-MKE
# 726 af 1000
# MKE-SFB
# 727 af 1000
# PGD-ROC
# 728 af 1000
# ROC-PGD
# 729 af 1000
# HNL-JFK
# 730 af 1000
# JFK-HNL
# 731 af 1000
# HNL-PPG
# 732 af 1000
# PPG-HNL
# 733 af 1000
# LIH-KOA
# 734 af 1000
# KOA-LIH
# 735 af 1000
# MIA-PNS
# 736 af 1000
# PNS-MIA
# 737 af 1000
# MIA-TLH
# 738 af 1000
# TLH-MIA
# 739 af 1000
# DFW-SUX
# 740 af 1000
# SUX-DFW
# 741 af 1000
# DFW-LCH
# 742 af 1000
# LCH-DFW
# 743 af 1000
# ILM-LGA
# 744 af 1000
# DFW-JLN
# 745 af 1000
# JLN-DFW
# 746 af 1000
# TLH-DFW
# 747 af 1000
# DFW-TLH
# 748 af 1000
# BHM-MIA
# 749 af 1000
# BIL-DFW
# 750 af 1000
# DFW-BIL
# 751 af 1000
# DFW-GCK
# 752 af 1000
# GCK-DFW
# 753 af 1000
# MIA-BHM
# 754 af 1000
# ORD-ALO
# 755 af 1000
# ALO-ORD
# 756 af 1000
# DFW-FAR
# 757 af 1000
# FAR-DFW
# 758 af 1000
# DFW-SPI
# 759 af 1000
# SPI-DFW
# 760 af 1000
# LGA-ROA
# 761 af 1000
# ROA-LGA
# 762 af 1000
# DFW-BPT
# 763 af 1000
# SGF-CLT
# 764 af 1000
# DFW-FSD
# 765 af 1000
# DFW-GJT
# 766 af 1000
# GJT-DFW
# 767 af 1000
# DFW-SWO
# 768 af 1000
# FSD-DFW
# 769 af 1000
# ORD-SUX
# 770 af 1000
# CHS-MIA
# 771 af 1000
# LGA-ILM
# 772 af 1000
# SWO-DFW
# 773 af 1000
# BZN-DFW
# 774 af 1000
# DFW-BZN
# 775 af 1000
# ORD-MHK
# 776 af 1000
# MHK-ORD
# 777 af 1000
# SUX-ORD
# 778 af 1000
# PNS-DCA
# 779 af 1000
# COU-ORD
# 780 af 1000
# ORD-COU
# 781 af 1000
# GNV-MIA
# 782 af 1000
# MIA-GNV
# 783 af 1000
# BIS-DFW
# 784 af 1000
# MIA-CHS
# 785 af 1000
# CLT-SGF
# 786 af 1000
# DCA-PNS
# 787 af 1000
# DFW-GRI
# 788 af 1000
# GRI-DFW
# 789 af 1000
# BPT-DFW
# 790 af 1000
# MGM-DFW
# 791 af 1000
# DFW-BIS
# 792 af 1000
# DFW-MGM
# 793 af 1000
# IAG-FLL
# 794 af 1000
# FLL-LBE
# 795 af 1000
# LBE-FLL
# 796 af 1000
# LBE-MCO
# 797 af 1000
# MCO-LBE
# 798 af 1000
# RSW-ACY
# 799 af 1000
# ACY-RSW
# 800 af 1000
# MYR-FLL
# 801 af 1000
# FLL-MYR
# 802 af 1000
# ACY-PBI
# 803 af 1000
# PBI-ACY
# 804 af 1000
# TPA-LBE
# 805 af 1000
# LBE-TPA
# 806 af 1000
# RSW-LBE
# 807 af 1000
# LBE-RSW
# 808 af 1000
# FLL-STT
# 809 af 1000
# STT-FLL
# 810 af 1000
# FLL-ACY
# 811 af 1000
# ACY-FLL
# 812 af 1000
# ACY-TPA
# 813 af 1000
# TPA-ACY
# 814 af 1000
# MYR-ACY
# 815 af 1000
# Not working for https://www.skyscanner.com/transport/flights/FLL/IAG/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# FLL-IAG
# 816 af 1000
# CLT-ROA
# 817 af 1000
# EWN-CLT
# 818 af 1000
# ROA-CLT
# 819 af 1000
# AUS-CLT
# 820 af 1000
# CLT-AUS
# 821 af 1000
# CLT-PHF
# 822 af 1000
# PHF-CLT
# 823 af 1000
# LEX-CLT
# 824 af 1000
# CLT-VPS
# 825 af 1000
# CLT-EWN
# 826 af 1000
# CHO-CLT
# 827 af 1000
# CLT-CHO
# 828 af 1000
# DCA-GSP
# 829 af 1000
# CLT-HPN
# 830 af 1000
# HPN-CLT
# 831 af 1000
# JAN-CLT
# 832 af 1000
# MCI-DCA
# 833 af 1000
# HVN-PHL
# 834 af 1000
# PHL-HVN
# 835 af 1000
# PHL-CAK
# 836 af 1000
# TYS-PHL
# 837 af 1000
# DCA-MCI
# 838 af 1000
# CLT-TOL
# 839 af 1000
# TOL-CLT
# 840 af 1000
# CLT-XNA
# 841 af 1000
# CRW-CLT
# 842 af 1000
# CLT-FAY
# 843 af 1000
# FAY-CLT
# 844 af 1000
# DAB-CLT
# 845 af 1000
# CHA-CLT
# 846 af 1000
# CLT-OMA
# 847 af 1000
# OMA-CLT
# 848 af 1000
# GSP-CLT
# 849 af 1000
# OAJ-CLT
# 850 af 1000
# CLT-MOB
# 851 af 1000
# MOB-CLT
# 852 af 1000
# CLT-SHV
# 853 af 1000
# SHV-CLT
# 854 af 1000
# AVL-CLT
# 855 af 1000
# CLT-AVL
# 856 af 1000
# Not working for https://www.skyscanner.com/transport/flights/SRQ/DCA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SRQ-DCA
# 857 af 1000
# CLT-LEX
# 858 af 1000
# MSN-CLT
# 859 af 1000
# GPT-CLT
# 860 af 1000
# PWM-DCA
# 861 af 1000
# DCA-PWM
# 862 af 1000
# CLT-JAN
# 863 af 1000
# GRR-CLT
# 864 af 1000
# CLT-OAJ
# 865 af 1000
# PIA-CLT
# 866 af 1000
# DCA-GSO
# 867 af 1000
# GSP-DCA
# 868 af 1000
# CAK-PHL
# 869 af 1000
# AVP-CLT
# 870 af 1000
# CLT-AVP
# 871 af 1000
# VPS-CLT
# 872 af 1000
# CLT-HSV
# 873 af 1000
# HSV-CLT
# 874 af 1000
# BHM-DCA
# 875 af 1000
# DCA-BHM
# 876 af 1000
# BTV-DCA
# 877 af 1000
# CLT-DAB
# 878 af 1000
# PWM-PHL
# 879 af 1000
# DCA-BTV
# 880 af 1000
# CLT-DAY
# 881 af 1000
# TYS-DCA
# 882 af 1000
# DCA-TYS
# 883 af 1000
# CLT-BTV
# 884 af 1000
# CLT-CHA
# 885 af 1000
# BTV-CLT
# 886 af 1000
# DCA-ROC
# 887 af 1000
# ROC-DCA
# 888 af 1000
# DCA-SDF
# 889 af 1000
# SDF-DCA
# 890 af 1000
# DCA-ORF
# 891 af 1000
# ORF-DCA
# 892 af 1000
# CHA-DCA
# 893 af 1000
# DCA-CHA
# 894 af 1000
# DCA-HPN
# 895 af 1000
# HPN-DCA
# 896 af 1000
# CID-CLT
# 897 af 1000
# CLT-MSN
# 898 af 1000
# CLT-EVV
# 899 af 1000
# EVV-CLT
# 900 af 1000
# CAK-CLT
# 901 af 1000
# CAE-CLT
# 902 af 1000
# CLT-CAE
# 903 af 1000
# DAY-PHL
# 904 af 1000
# CRW-DCA
# 905 af 1000
# CLT-TUL
# 906 af 1000
# TUL-CLT
# 907 af 1000
# CLT-DSM
# 908 af 1000
# CLT-MLB
# 909 af 1000
# MLB-CLT
# 910 af 1000
# CAE-DCA
# 911 af 1000
# DCA-CAE
# 912 af 1000
# CLT-GNV
# 913 af 1000
# GNV-CLT
# 914 af 1000
# CLT-GPT
# 915 af 1000
# CLT-GSP
# 916 af 1000
# PHL-PWM
# 917 af 1000
# DCA-DAY
# 918 af 1000
# DSM-CLT
# 919 af 1000
# PHL-BHM
# 920 af 1000
# DAY-DCA
# 921 af 1000
# PHL-DAY
# 922 af 1000
# GSO-PHL
# 923 af 1000
# PHL-GSO
# 924 af 1000
# DAY-CLT
# 925 af 1000
# CLT-OKC
# 926 af 1000
# OKC-CLT
# 927 af 1000
# DCA-CRW
# 928 af 1000
# CLT-CAK
# 929 af 1000
# CLT-FWA
# 930 af 1000
# FWA-CLT
# 931 af 1000
# Not working for https://www.skyscanner.com/transport/flights/DCA/VPS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DCA-VPS
# 932 af 1000
# Not working for https://www.skyscanner.com/transport/flights/VPS/DCA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# VPS-DCA
# 933 af 1000
# XNA-CLT
# 934 af 1000
# CLT-LYH
# 935 af 1000
# LYH-CLT
# 936 af 1000
# BHM-PHL
# 937 af 1000
# CLT-CRW
# 938 af 1000
# CHS-PHL
# 939 af 1000
# PHL-CHS
# 940 af 1000
# DCA-CAK
# 941 af 1000
# CRW-PHL
# 942 af 1000
# CLT-CID
# 943 af 1000
# PHL-TYS
# 944 af 1000
# CAK-DCA
# 945 af 1000
# Not working for https://www.skyscanner.com/transport/flights/DCA/SRQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DCA-SRQ
# 946 af 1000
# CLT-MGM
# 947 af 1000
# MGM-CLT
# 948 af 1000
# DCA-MYR
# 949 af 1000
# MYR-DCA
# 950 af 1000
# PHL-CRW
# 951 af 1000
# CLT-PIA
# 952 af 1000
# ASE-DFW
# 953 af 1000
# DFW-ASE
# 954 af 1000
# EGE-PHX
# 955 af 1000
# PHX-EGE
# 956 af 1000
# RDM-LAX
# 957 af 1000
# LAX-RDM
# 958 af 1000
# RDM-PHX
# 959 af 1000
# LBB-PHX
# 960 af 1000
# STS-PHX
# 961 af 1000
# ROW-PHX
# 962 af 1000
# MTJ-PHX
# 963 af 1000
# PHX-MTJ
# 964 af 1000
# PHX-SAF
# 965 af 1000
# PHX-STS
# 966 af 1000
# PHX-ROW
# 967 af 1000
# CHO-ORD
# 968 af 1000
# ORD-CHO
# 969 af 1000
# MEI-DFW
# 970 af 1000
# PIB-MEI
# 971 af 1000
# DFW-PIB
# 972 af 1000
# MEI-ORD
# 973 af 1000
# MEI-PIB
# 974 af 1000
# ORD-MEI
# 975 af 1000
# PHX-SGU
# 976 af 1000
# SGU-PHX
# 977 af 1000
# SAF-PHX
# 978 af 1000
# PHX-LBB
# 979 af 1000
# PHX-RDM
# 980 af 1000
# BIS-ORD
# 981 af 1000
# ORD-BIS
# 982 af 1000
# TUS-SJC
# 983 af 1000
# TUS-SJC
# 984 af 1000
# SJC-TUS
# 985 af 1000
# SJC-TUS
# 986 af 1000
# PDX-DAL
# 987 af 1000
# DAL-PDX
# 988 af 1000
# DAL-LGA
# 989 af 1000
# LGA-DAL
# 990 af 1000
# PDX-BZN
# 991 af 1000
# BZN-PDX
# 992 af 1000
# SEA-DAL
# 993 af 1000
# BZN-SEA
# 994 af 1000
# DAL-SEA
# 995 af 1000
# PDX-BLI
# 996 af 1000
# PSC-SEA
# 997 af 1000
# SEA-BZN
# 998 af 1000
# MKE-SEA
# 999 af 1000
# SEA-MKE
# 1000 af 1000

# %% [markdown]
# ### MORTEN

# %%
# Indsæt driverpath (skal vise lokal path)
prices2=skyscannerscraper(data2['Origin'],data2['Dest'],190527,save="missings_2018_del3", driverpath='C:/Users/Morte/Documents/GitHub/TSDS-gruppe-2019/Exam/geckodriver_win64', direct='false')
# Out:
# HIB-MSP
# 1 af 721
# MSP-HIB
# 2 af 721
# MSP-CIU
# 3 af 721
# CIU-DTW
# 4 af 721
# DTW-CIU
# 5 af 721
# BRD-MSP
# 6 af 721
# MQT-MSP
# 7 af 721
# MSP-IMT
# 8 af 721
# ORD-CGI
# 9 af 721
# ORD-CGI
# 10 af 721
# CGI-ORD
# 11 af 721
# CGI-ORD
# 12 af 721
# DVL-JMS
# 13 af 721
# JMS-DEN
# 14 af 721
# Not working for https://www.skyscanner.com/transport/flights/PLN/APN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PLN-APN
# 15 af 721
# BIL-PDX
# 16 af 721
# PDX-BIL
# 17 af 721
# APN-PLN
# 18 af 721
# XNA-SFO
# 19 af 721
# LIT-DEN
# 20 af 721
# FSD-PHX
# 21 af 721
# PHX-FSD
# 22 af 721
# XNA-CVG
# 23 af 721
# CVG-XNA
# 24 af 721
# SFO-XNA
# 25 af 721
# ORD-GTF
# 26 af 721
# BFF-DEN
# 27 af 721
# DAL-SFO
# 28 af 721
# DAL-DCA
# 29 af 721
# SFO-DAL
# 30 af 721
# DCA-DAL
# 31 af 721
# LAX-DAL
# 32 af 721
# DAL-LAX
# 33 af 721
# ALB-DEN
# 34 af 721
# AMA-DAL
# 35 af 721
# ATL-DAL
# 36 af 721
# AUS-DCA
# 37 af 721
# AUS-OAK
# 38 af 721
# BNA-CHS
# 39 af 721
# BNA-DAL
# 40 af 721
# Not working for https://www.skyscanner.com/transport/flights/BNA/ECP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BNA-ECP
# 41 af 721
# BNA-MKE
# 42 af 721
# BNA-PIT
# 43 af 721
# BNA-PNS
# 44 af 721
# BOI-SMF
# 45 af 721
# BOS-DAL
# 46 af 721
# BUR-DAL
# 47 af 721
# BWI-CHS
# 48 af 721
# BWI-DAL
# 49 af 721
# BWI-GRR
# 50 af 721
# BWI-SJC
# 51 af 721
# BWI-SMF
# 52 af 721
# CHS-BNA
# 53 af 721
# CHS-BWI
# 54 af 721
# CHS-HOU
# 55 af 721
# CHS-MDW
# 56 af 721
# CLT-DAL
# 57 af 721
# CLT-HOU
# 58 af 721
# CMH-DAL
# 59 af 721
# CMH-OAK
# 60 af 721
# CVG-MDW
# 61 af 721
# DAL-AMA
# 62 af 721
# DAL-ATL
# 63 af 721
# DAL-BNA
# 64 af 721
# DAL-BOS
# 65 af 721
# DAL-BUR
# 66 af 721
# DAL-BWI
# 67 af 721
# DAL-CLT
# 68 af 721
# DAL-CMH
# 69 af 721
# DAL-DEN
# 70 af 721
# DAL-DTW
# 71 af 721
# DAL-FLL
# 72 af 721
# DAL-HOU
# 73 af 721
# DAL-IND
# 74 af 721
# DAL-LAS
# 75 af 721
# DAL-MCO
# 76 af 721
# DAL-MDW
# 77 af 721
# DAL-MEM
# 78 af 721
# DAL-MKE
# 79 af 721
# DAL-OAK
# 80 af 721
# DAL-OMA
# 81 af 721
# DAL-OMA
# 82 af 721
# DAL-ONT
# 83 af 721
# DAL-PHL
# 84 af 721
# DAL-PHX
# 85 af 721
# DAL-PIT
# 86 af 721
# DAL-RDU
# 87 af 721
# DAL-SAN
# 88 af 721
# DAL-SJC
# 89 af 721
# DAL-SLC
# 90 af 721
# DAL-SMF
# 91 af 721
# DAL-SNA
# 92 af 721
# DAL-TPA
# 93 af 721
# DCA-AUS
# 94 af 721
# DCA-HOU
# 95 af 721
# DCA-MDW
# 96 af 721
# DCA-MKE
# 97 af 721
# DCA-OMA
# 98 af 721
# DEN-ALB
# 99 af 721
# DEN-DAL
# 100 af 721
# Not working for https://www.skyscanner.com/transport/flights/DEN/LGB/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DEN-LGB
# 101 af 721
# DSM-STL
# 102 af 721
# DTW-DAL
# 103 af 721
# ECP-BNA
# 104 af 721
# ECP-HOU
# 105 af 721
# FLL-DAL
# 106 af 721
# FLL-MCI
# 107 af 721
# FNT-MDW
# 108 af 721
# GRR-BWI
# 109 af 721
# GRR-MDW
# 110 af 721
# HOU-CHS
# 111 af 721
# HOU-CLT
# 112 af 721
# HOU-DAL
# 113 af 721
# HOU-DCA
# 114 af 721
# HOU-ECP
# 115 af 721
# HOU-IND
# 116 af 721
# HOU-LGA
# 117 af 721
# HOU-MCI
# 118 af 721
# HOU-MEM
# 119 af 721
# HOU-OMA
# 120 af 721
# HOU-PIT
# 121 af 721
# HOU-PNS
# 122 af 721
# HOU-RDU
# 123 af 721
# HOU-SNA
# 124 af 721
# ICT-STL
# 125 af 721
# IND-DAL
# 126 af 721
# IND-HOU
# 127 af 721
# JAX-MDW
# 128 af 721
# LAS-DAL
# 129 af 721
# LGA-HOU
# 130 af 721
# LGA-MDW
# 131 af 721
# Not working for https://www.skyscanner.com/transport/flights/LGB/DEN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LGB-DEN
# 132 af 721
# MCI-FLL
# 133 af 721
# MCI-HOU
# 134 af 721
# Not working for https://www.skyscanner.com/transport/flights/MCI/MKE/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCI-MKE
# 135 af 721
# MCO-DAL
# 136 af 721
# MDW-CHS
# 137 af 721
# MDW-CVG
# 138 af 721
# MDW-DAL
# 139 af 721
# MDW-DCA
# 140 af 721
# MDW-FNT
# 141 af 721
# MDW-GRR
# 142 af 721
# MDW-JAX
# 143 af 721
# Not working for https://www.skyscanner.com/transport/flights/MDW/MEM/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-MEM
# 144 af 721
# MDW-OKC
# 145 af 721
# MDW-ONT
# 146 af 721
# MEM-DAL
# 147 af 721
# MEM-HOU
# 148 af 721
# MEM-MDW
# 149 af 721
# MKE-BNA
# 150 af 721
# MKE-DAL
# 151 af 721
# MKE-DCA
# 152 af 721
# MKE-STL
# 153 af 721
# MSY-OAK
# 154 af 721
# MSY-SAN
# 155 af 721
# OAK-AUS
# 156 af 721
# OAK-CMH
# 157 af 721
# OAK-DAL
# 158 af 721
# OAK-MSY
# 159 af 721
# OAK-STL
# 160 af 721
# OKC-MDW
# 161 af 721
# OMA-DAL
# 162 af 721
# OMA-DAL
# 163 af 721
# OMA-DCA
# 164 af 721
# OMA-HOU
# 165 af 721
# ONT-DAL
# 166 af 721
# ONT-MDW
# 167 af 721
# PDX-STL
# 168 af 721
# PHL-DAL
# 169 af 721
# PHX-DAL
# 170 af 721
# PIT-BNA
# 171 af 721
# PIT-DAL
# 172 af 721
# PIT-HOU
# 173 af 721
# PIT-STL
# 174 af 721
# PNS-BNA
# 175 af 721
# PNS-HOU
# 176 af 721
# RDU-DAL
# 177 af 721
# RDU-HOU
# 178 af 721
# SAN-DAL
# 179 af 721
# SAN-MSY
# 180 af 721
# SJC-BWI
# 181 af 721
# SJC-DAL
# 182 af 721
# SLC-DAL
# 183 af 721
# SMF-BOI
# 184 af 721
# SMF-BWI
# 185 af 721
# SMF-DAL
# 186 af 721
# SNA-DAL
# 187 af 721
# SNA-HOU
# 188 af 721
# STL-DSM
# 189 af 721
# STL-ICT
# 190 af 721
# STL-MKE
# 191 af 721
# STL-OAK
# 192 af 721
# STL-PDX
# 193 af 721
# STL-PHL
# 194 af 721
# STL-PIT
# 195 af 721
# TPA-DAL
# 196 af 721
# CHS-DAL
# 197 af 721
# CMH-HOU
# 198 af 721
# DAL-CHS
# 199 af 721
# HOU-CMH
# 200 af 721
# HOU-SLC
# 201 af 721
# SJU-MDW
# 202 af 721
# SAN-TPA
# 203 af 721
# TPA-SAN
# 204 af 721
# Not working for https://www.skyscanner.com/transport/flights/HOU/SJU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# HOU-SJU
# 205 af 721
# Not working for https://www.skyscanner.com/transport/flights/SJU/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SJU-HOU
# 206 af 721
# MDW-SJU
# 207 af 721
# Not working for https://www.skyscanner.com/transport/flights/CMH/MSY/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CMH-MSY
# 208 af 721
# Not working for https://www.skyscanner.com/transport/flights/MSY/CMH/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-CMH
# 209 af 721
# IAD-IND
# 210 af 721
# IND-IAD
# 211 af 721
# BOI-IAH
# 212 af 721
# IAH-BOI
# 213 af 721
# IAD-TYS
# 214 af 721
# TYS-IAD
# 215 af 721
# OKC-IAD
# 216 af 721
# CMH-IAD
# 217 af 721
# IAD-CMH
# 218 af 721
# DFW-RAP
# 219 af 721
# RAP-DFW
# 220 af 721
# BMI-DFW
# 221 af 721
# DRO-DFW
# 222 af 721
# DFW-BMI
# 223 af 721
# BRO-DFW
# 224 af 721
# DFW-BRO
# 225 af 721
# PHX-MAF
# 226 af 721
# MAF-PHX
# 227 af 721
# DFW-DRO
# 228 af 721
# DFW-MYR
# 229 af 721
# MYR-DFW
# 230 af 721
# BTV-IAD
# 231 af 721
# IAD-BTV
# 232 af 721
# IAD-RIC
# 233 af 721
# RIC-IAD
# 234 af 721
# BZN-IAH
# 235 af 721
# IAH-BZN
# 236 af 721
# AUS-MIA
# 237 af 721
# MIA-AUS
# 238 af 721
# DCA-BGR
# 239 af 721
# ILM-PHL
# 240 af 721
# PHL-ILM
# 241 af 721
# MCI-PHL
# 242 af 721
# EYW-MIA
# 243 af 721
# MIA-EYW
# 244 af 721
# MIA-OMA
# 245 af 721
# PHL-MCI
# 246 af 721
# CLT-EYW
# 247 af 721
# EYW-CLT
# 248 af 721
# OMA-MIA
# 249 af 721
# PHL-SAV
# 250 af 721
# SAV-PHL
# 251 af 721
# Not working for https://www.skyscanner.com/transport/flights/DCA/EYW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DCA-EYW
# 252 af 721
# Not working for https://www.skyscanner.com/transport/flights/EYW/DCA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# EYW-DCA
# 253 af 721
# BGR-DCA
# 254 af 721
# LGA-PHL
# 255 af 721
# EWR-EYW
# 256 af 721
# EYW-EWR
# 257 af 721
# EYW-ORD
# 258 af 721
# ORD-EYW
# 259 af 721
# CLT-SMF
# 260 af 721
# SMF-CLT
# 261 af 721
# DFW-GEG
# 262 af 721
# SAT-CLT
# 263 af 721
# CLT-SAT
# 264 af 721
# BOI-DFW
# 265 af 721
# MIA-SLC
# 266 af 721
# DFW-BOI
# 267 af 721
# SLC-MIA
# 268 af 721
# MIA-SAN
# 269 af 721
# GEG-DFW
# 270 af 721
# SAN-MIA
# 271 af 721
# AUS-PHL
# 272 af 721
# PHL-AUS
# 273 af 721
# DFW-KOA
# 274 af 721
# KOA-DFW
# 275 af 721
# EGE-JFK
# 276 af 721
# MIA-SAT
# 277 af 721
# JFK-EGE
# 278 af 721
# SAT-MIA
# 279 af 721
# SAT-JFK
# 280 af 721
# JFK-SAT
# 281 af 721
# Not working for https://www.skyscanner.com/transport/flights/STX/ATL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# STX-ATL
# 282 af 721
# Not working for https://www.skyscanner.com/transport/flights/ATL/STX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ATL-STX
# 283 af 721
# Not working for https://www.skyscanner.com/transport/flights/MSP/HNL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSP-HNL
# 284 af 721
# Not working for https://www.skyscanner.com/transport/flights/HNL/MSP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# HNL-MSP
# 285 af 721
# Not working for https://www.skyscanner.com/transport/flights/ATL/BZN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ATL-BZN
# 286 af 721
# Not working for https://www.skyscanner.com/transport/flights/BZN/ATL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BZN-ATL
# 287 af 721
# DTW-SNA
# 288 af 721
# SNA-DTW
# 289 af 721
# CHS-DEN
# 290 af 721
# DEN-CHS
# 291 af 721
# Not working for https://www.skyscanner.com/transport/flights/IND/MSY/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# IND-MSY
# 292 af 721
# Not working for https://www.skyscanner.com/transport/flights/MSY/IND/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-IND
# 293 af 721
# IAD-STL
# 294 af 721
# PHL-SDF
# 295 af 721
# SDF-PHL
# 296 af 721
# BGR-PHL
# 297 af 721
# PHL-BGR
# 298 af 721
# SAT-PHL
# 299 af 721
# CLT-TUS
# 300 af 721
# TUS-CLT
# 301 af 721
# PHL-SAT
# 302 af 721
# IND-SAV
# 303 af 721
# SAV-IND
# 304 af 721
# SDF-SAV
# 305 af 721
# SAV-SDF
# 306 af 721
# CLE-SAV
# 307 af 721
# SAV-CLE
# 308 af 721
# BWI-SAV
# 309 af 721
# SAV-BWI
# 310 af 721
# PIT-SAV
# 311 af 721
# SAV-PIT
# 312 af 721
# LCK-SAV
# 313 af 721
# SAV-LCK
# 314 af 721
# LCK-AUS
# 315 af 721
# SFB-OKC
# 316 af 721
# OKC-SFB
# 317 af 721
# CLT-FLO
# 318 af 721
# FLO-CLT
# 319 af 721
# MYR-IAG
# 320 af 721
# IAG-MYR
# 321 af 721
# MYR-LBE
# 322 af 721
# LBE-MYR
# 323 af 721
# BWI-MYR
# 324 af 721
# MYR-BWI
# 325 af 721
# DCA-TLH
# 326 af 721
# TLH-DCA
# 327 af 721
# DEN-LBF
# 328 af 721
# LBF-DEN
# 329 af 721
# SEA-ICT
# 330 af 721
# ICT-SEA
# 331 af 721
# LBL-PUB
# 332 af 721
# PUB-LBL
# 333 af 721
# DEN-LBL
# 334 af 721
# LBL-DEN
# 335 af 721
# SCK-SAN
# 336 af 721
# SAN-SCK
# 337 af 721
# PIT-RDU
# 338 af 721
# RDU-PIT
# 339 af 721
# MYR-ORD
# 340 af 721
# ORD-MYR
# 341 af 721
# MYR-BDL
# 342 af 721
# BDL-MYR
# 343 af 721
# CMH-MYR
# 344 af 721
# MYR-CMH
# 345 af 721
# CLE-MYR
# 346 af 721
# MYR-CLE
# 347 af 721
# MSO-SEA
# 348 af 721
# PDX-TUS
# 349 af 721
# TUS-PDX
# 350 af 721
# SEA-MSO
# 351 af 721
# BWI-ECP
# 352 af 721
# Not working for https://www.skyscanner.com/transport/flights/DAL/ECP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DAL-ECP
# 353 af 721
# ECP-BWI
# 354 af 721
# Not working for https://www.skyscanner.com/transport/flights/ECP/DAL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ECP-DAL
# 355 af 721
# ECP-STL
# 356 af 721
# HOU-MKE
# 357 af 721
# MKE-HOU
# 358 af 721
# Not working for https://www.skyscanner.com/transport/flights/STL/ECP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# STL-ECP
# 359 af 721
# DAL-JAX
# 360 af 721
# JAX-DAL
# 361 af 721
# Not working for https://www.skyscanner.com/transport/flights/MDW/PNS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-PNS
# 362 af 721
# Not working for https://www.skyscanner.com/transport/flights/PNS/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PNS-MDW
# 363 af 721
# SMF-MSY
# 364 af 721
# MSY-SMF
# 365 af 721
# MSP-SYR
# 366 af 721
# SYR-MSP
# 367 af 721
# COS-SAT
# 368 af 721
# AUS-CHS
# 369 af 721
# CHS-AUS
# 370 af 721
# AUS-RNO
# 371 af 721
# RNO-AUS
# 372 af 721
# Not working for https://www.skyscanner.com/transport/flights/PVD/DEN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-DEN
# 373 af 721
# Not working for https://www.skyscanner.com/transport/flights/TTN/DTW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# TTN-DTW
# 374 af 721
# Not working for https://www.skyscanner.com/transport/flights/DTW/TTN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DTW-TTN
# 375 af 721
# Not working for https://www.skyscanner.com/transport/flights/BUF/DEN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BUF-DEN
# 376 af 721
# Not working for https://www.skyscanner.com/transport/flights/COS/IAD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# COS-IAD
# 377 af 721
# SAT-SJC
# 378 af 721
# Not working for https://www.skyscanner.com/transport/flights/DEN/BUF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DEN-BUF
# 379 af 721
# SJC-SAT
# 380 af 721
# Not working for https://www.skyscanner.com/transport/flights/IAD/COS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# IAD-COS
# 381 af 721
# OMA-PHL
# 382 af 721
# PHL-OMA
# 383 af 721
# AUS-OMA
# 384 af 721
# OMA-AUS
# 385 af 721
# ORD-TTN
# 386 af 721
# ORD-TTN
# 387 af 721
# TTN-ORD
# 388 af 721
# TTN-ORD
# 389 af 721
# ORD-ISP
# 390 af 721
# ISP-SJU
# 391 af 721
# Not working for https://www.skyscanner.com/transport/flights/DEN/PVD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DEN-PVD
# 392 af 721
# SJU-ISP
# 393 af 721
# ISP-ORD
# 394 af 721
# RDU-TTN
# 395 af 721
# AUS-MKE
# 396 af 721
# MKE-AUS
# 397 af 721
# Not working for https://www.skyscanner.com/transport/flights/TTN/JAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# TTN-JAX
# 398 af 721
# Not working for https://www.skyscanner.com/transport/flights/JAX/TTN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# JAX-TTN
# 399 af 721
# TTN-RDU
# 400 af 721
# Not working for https://www.skyscanner.com/transport/flights/RDU/BUF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RDU-BUF
# 401 af 721
# Not working for https://www.skyscanner.com/transport/flights/BUF/RDU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BUF-RDU
# 402 af 721
# Not working for https://www.skyscanner.com/transport/flights/RDU/SJU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RDU-SJU
# 403 af 721
# Not working for https://www.skyscanner.com/transport/flights/SJU/RDU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SJU-RDU
# 404 af 721
# SJC-TUL
# 405 af 721
# TUL-IAD
# 406 af 721
# IAD-TUL
# 407 af 721
# TUL-SJC
# 408 af 721
# Not working for https://www.skyscanner.com/transport/flights/MCO/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCO-ABQ
# 409 af 721
# Not working for https://www.skyscanner.com/transport/flights/TTN/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# TTN-BNA
# 410 af 721
# Not working for https://www.skyscanner.com/transport/flights/BNA/TTN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BNA-TTN
# 411 af 721
# TTN-CHS
# 412 af 721
# CHS-TTN
# 413 af 721
# MSP-TTN
# 414 af 721
# Not working for https://www.skyscanner.com/transport/flights/MCO/TUL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCO-TUL
# 415 af 721
# Not working for https://www.skyscanner.com/transport/flights/TUL/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# TUL-MCO
# 416 af 721
# COS-SEA
# 417 af 721
# SEA-COS
# 418 af 721
# Not working for https://www.skyscanner.com/transport/flights/DEN/PNS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DEN-PNS
# 419 af 721
# Not working for https://www.skyscanner.com/transport/flights/PNS/DEN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PNS-DEN
# 420 af 721
# AUS-BUF
# 421 af 721
# BUF-AUS
# 422 af 721
# TTN-MSP
# 423 af 721
# CVG-SJC
# 424 af 721
# SJC-CVG
# 425 af 721
# MSN-PHL
# 426 af 721
# PHL-MSN
# 427 af 721
# PDX-CLE
# 428 af 721
# CLE-PDX
# 429 af 721
# Not working for https://www.skyscanner.com/transport/flights/CVG/SAN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CVG-SAN
# 430 af 721
# Not working for https://www.skyscanner.com/transport/flights/RDU/PVD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RDU-PVD
# 431 af 721
# Not working for https://www.skyscanner.com/transport/flights/PVD/RDU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-RDU
# 432 af 721
# Not working for https://www.skyscanner.com/transport/flights/SAN/CVG/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SAN-CVG
# 433 af 721
# AUS-CMH
# 434 af 721
# CMH-AUS
# 435 af 721
# Not working for https://www.skyscanner.com/transport/flights/RDU/MKE/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RDU-MKE
# 436 af 721
# Not working for https://www.skyscanner.com/transport/flights/MKE/RDU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MKE-RDU
# 437 af 721
# PHL-GRR
# 438 af 721
# GRR-PHL
# 439 af 721
# Not working for https://www.skyscanner.com/transport/flights/ABQ/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ABQ-MCO
# 440 af 721
# PIT-CHS
# 441 af 721
# CHS-PIT
# 442 af 721
# LCK-MYR
# 443 af 721
# MYR-LCK
# 444 af 721
# MYR-MDT
# 445 af 721
# MDT-MYR
# 446 af 721
# ABE-MYR
# 447 af 721
# MYR-ABE
# 448 af 721
# IND-CHS
# 449 af 721
# PIT-SRQ
# 450 af 721
# SRQ-PIT
# 451 af 721
# DCA-LIT
# 452 af 721
# CLT-HTS
# 453 af 721
# HTS-CLT
# 454 af 721
# LIT-DCA
# 455 af 721
# MSY-ACY
# 456 af 721
# ACY-MSY
# 457 af 721
# DTW-OAK
# 458 af 721
# OAK-DTW
# 459 af 721
# GSP-PHL
# 460 af 721
# PHL-GSP
# 461 af 721
# CLT-PGV
# 462 af 721
# PGV-CLT
# 463 af 721
# PHF-PHL
# 464 af 721
# PHL-PHF
# 465 af 721
# DCA-ILM
# 466 af 721
# Not working for https://www.skyscanner.com/transport/flights/ILM/DCA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ILM-DCA
# 467 af 721
# CAE-PHL
# 468 af 721
# PHL-CAE
# 469 af 721
# LWB-SHD
# 470 af 721
# ORD-LWB
# 471 af 721
# SHD-IAD
# 472 af 721
# IAD-SHD
# 473 af 721
# LWB-ORD
# 474 af 721
# SHD-LWB
# 475 af 721
# ORD-SLN
# 476 af 721
# SLN-HYS
# 477 af 721
# HYS-SLN
# 478 af 721
# SLN-ORD
# 479 af 721
# IAD-LWB
# 480 af 721
# LWB-IAD
# 481 af 721
# BIL-SEA
# 482 af 721
# PDX-OMA
# 483 af 721
# OMA-PDX
# 484 af 721
# ILM-ORD
# 485 af 721
# ORD-ILM
# 486 af 721
# BOI-SJC
# 487 af 721
# EWR-OAK
# 488 af 721
# GEG-SJC
# 489 af 721
# HOU-PDX
# 490 af 721
# HOU-SJC
# 491 af 721
# OAK-EWR
# 492 af 721
# PDX-HOU
# 493 af 721
# SJC-BOI
# 494 af 721
# SJC-GEG
# 495 af 721
# SJC-HOU
# 496 af 721
# SJC-STL
# 497 af 721
# SMF-STL
# 498 af 721
# STL-SJC
# 499 af 721
# STL-SMF
# 500 af 721
# AUS-SMF
# 501 af 721
# MCO-OAK
# 502 af 721
# OAK-MCO
# 503 af 721
# Not working for https://www.skyscanner.com/transport/flights/SJC/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SJC-ABQ
# 504 af 721
# PHX-AMA
# 505 af 721
# AMA-PHX
# 506 af 721
# Not working for https://www.skyscanner.com/transport/flights/STT/IAD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# STT-IAD
# 507 af 721
# Not working for https://www.skyscanner.com/transport/flights/IAD/STT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# IAD-STT
# 508 af 721
# DEN-SAV
# 509 af 721
# SAV-DEN
# 510 af 721
# ISP-MYR
# 511 af 721
# MYR-PVD
# 512 af 721
# PVD-MYR
# 513 af 721
# MYR-ISP
# 514 af 721
# Not working for https://www.skyscanner.com/transport/flights/TTN/MYR/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# TTN-MYR
# 515 af 721
# Not working for https://www.skyscanner.com/transport/flights/MYR/TTN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MYR-TTN
# 516 af 721
# VPS-SGF
# 517 af 721
# SGF-VPS
# 518 af 721
# VPS-OKC
# 519 af 721
# OKC-VPS
# 520 af 721
# VPS-MCI
# 521 af 721
# MCI-VPS
# 522 af 721
# VPS-SDF
# 523 af 721
# SDF-VPS
# 524 af 721
# MYR-HTS
# 525 af 721
# HTS-MYR
# 526 af 721
# MYR-SWF
# 527 af 721
# SWF-MYR
# 528 af 721
# LAX-MSO
# 529 af 721
# MSO-LAX
# 530 af 721
# VPS-LCK
# 531 af 721
# LCK-VPS
# 532 af 721
# VPS-AUS
# 533 af 721
# AUS-VPS
# 534 af 721
# SFB-SYR
# 535 af 721
# SYR-SFB
# 536 af 721
# HNL-LGB
# 537 af 721
# CNY-DEN
# 538 af 721
# DEN-CNY
# 539 af 721
# SAN-STS
# 540 af 721
# STS-SAN
# 541 af 721
# MCO-SJC
# 542 af 721
# MCO-SMF
# 543 af 721
# SJC-MCO
# 544 af 721
# SMF-MCO
# 545 af 721
# Not working for https://www.skyscanner.com/transport/flights/STL/CHS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# STL-CHS
# 546 af 721
# Not working for https://www.skyscanner.com/transport/flights/CHS/STL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CHS-STL
# 547 af 721
# ORF-DEN
# 548 af 721
# DEN-ORF
# 549 af 721
# DSM-PHL
# 550 af 721
# PHL-DSM
# 551 af 721
# CLT-SJC
# 552 af 721
# SJC-CLT
# 553 af 721
# LAX-OMA
# 554 af 721
# OMA-LAX
# 555 af 721
# JFK-ORH
# 556 af 721
# BOS-SMF
# 557 af 721
# SMF-BOS
# 558 af 721
# ORH-JFK
# 559 af 721
# MVY-JFK
# 560 af 721
# ACK-BOS
# 561 af 721
# BOS-ACK
# 562 af 721
# JFK-MVY
# 563 af 721
# ACK-DCA
# 564 af 721
# DCA-ACK
# 565 af 721
# HYA-JFK
# 566 af 721
# JFK-HYA
# 567 af 721
# DSM-SFO
# 568 af 721
# SFO-DSM
# 569 af 721
# DEN-BKG
# 570 af 721
# BKG-DEN
# 571 af 721
# CAK-IAH
# 572 af 721
# IAH-CAK
# 573 af 721
# TVC-EWR
# 574 af 721
# SBN-DFW
# 575 af 721
# SBN-CLT
# 576 af 721
# CLT-ECP
# 577 af 721
# CLT-SBN
# 578 af 721
# DFW-ECP
# 579 af 721
# DFW-SBN
# 580 af 721
# ECP-DFW
# 581 af 721
# ECP-CLT
# 582 af 721
# DFW-TVC
# 583 af 721
# TVC-DFW
# 584 af 721
# EWR-TVC
# 585 af 721
# PGD-BNA
# 586 af 721
# BNA-PGD
# 587 af 721
# VPS-EWR
# 588 af 721
# EWR-VPS
# 589 af 721
# VPS-BWI
# 590 af 721
# BWI-VPS
# 591 af 721
# BNA-RIC
# 592 af 721
# RIC-BNA
# 593 af 721
# PIE-BNA
# 594 af 721
# BNA-PIE
# 595 af 721
# LGB-HNL
# 596 af 721
# Not working for https://www.skyscanner.com/transport/flights/ORD/MSO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORD-MSO
# 597 af 721
# SAV-MIA
# 598 af 721
# MIA-SAV
# 599 af 721
# Not working for https://www.skyscanner.com/transport/flights/MSO/ORD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSO-ORD
# 600 af 721
# DFW-MSO
# 601 af 721
# MSO-DFW
# 602 af 721
# Not working for https://www.skyscanner.com/transport/flights/DCA/MGM/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DCA-MGM
# 603 af 721
# Not working for https://www.skyscanner.com/transport/flights/MGM/DCA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MGM-DCA
# 604 af 721
# BGR-CLT
# 605 af 721
# CLT-BGR
# 606 af 721
# LBB-DEN
# 607 af 721
# MSO-SFO
# 608 af 721
# DEN-LBB
# 609 af 721
# ORD-FAT
# 610 af 721
# SFO-FCA
# 611 af 721
# FAT-ORD
# 612 af 721
# FCA-SFO
# 613 af 721
# ACV-LAX
# 614 af 721
# ORD-SCE
# 615 af 721
# SCE-ORD
# 616 af 721
# SFO-MSN
# 617 af 721
# LAX-ACV
# 618 af 721
# MSN-SFO
# 619 af 721
# SFO-MSO
# 620 af 721
# GTF-ORD
# 621 af 721
# JAC-PHX
# 622 af 721
# PHX-JAC
# 623 af 721
# PDX-MKE
# 624 af 721
# MKE-PDX
# 625 af 721
# SEA-BIL
# 626 af 721
# DEN-VEL
# 627 af 721
# VEL-DEN
# 628 af 721
# BOI-MDW
# 629 af 721
# BWI-PDX
# 630 af 721
# GEG-MDW
# 631 af 721
# HOU-SEA
# 632 af 721
# IND-SAN
# 633 af 721
# MDW-BOI
# 634 af 721
# MDW-GEG
# 635 af 721
# MKE-SAN
# 636 af 721
# MKE-SFO
# 637 af 721
# PDX-BWI
# 638 af 721
# SAN-IND
# 639 af 721
# SAN-MKE
# 640 af 721
# SEA-HOU
# 641 af 721
# SFO-MKE
# 642 af 721
# IAD-ALB
# 643 af 721
# ALB-IAD
# 644 af 721
# LGA-MVY
# 645 af 721
# MVY-LGA
# 646 af 721
# PHL-PNS
# 647 af 721
# PNS-PHL
# 648 af 721
# ACK-LGA
# 649 af 721
# LGA-ACK
# 650 af 721
# OKC-PHL
# 651 af 721
# PHL-OKC
# 652 af 721
# DCA-MVY
# 653 af 721
# MVY-DCA
# 654 af 721
# SFO-BDL
# 655 af 721
# FAI-ORD
# 656 af 721
# ORD-FAI
# 657 af 721
# BDL-SFO
# 658 af 721
# GUM-SPN
# 659 af 721
# SPN-GUM
# 660 af 721
# MVY-BOS
# 661 af 721
# BOS-MVY
# 662 af 721
# LGA-CHA
# 663 af 721
# CHA-LGA
# 664 af 721
# FLL-SAT
# 665 af 721
# IND-OAK
# 666 af 721
# MSP-OAK
# 667 af 721
# OAK-IND
# 668 af 721
# OAK-MSP
# 669 af 721
# OAK-SAT
# 670 af 721
# SAT-FLL
# 671 af 721
# SAT-OAK
# 672 af 721
# CLT-HHH
# 673 af 721
# HHH-CLT
# 674 af 721
# RDM-SEA
# 675 af 721
# SEA-RDM
# 676 af 721
# DEN-PWM
# 677 af 721
# PWM-RDU
# 678 af 721
# RDU-PWM
# 679 af 721
# PWM-DEN
# 680 af 721
# STS-PDX
# 681 af 721
# PDX-STS
# 682 af 721
# IAD-PBG
# 683 af 721
# PBG-IAD
# 684 af 721
# DEN-PRC
# 685 af 721
# PRC-LAX
# 686 af 721
# LAX-PRC
# 687 af 721
# SDF-IAD
# 688 af 721
# BDL-STL
# 689 af 721
# STL-BDL
# 690 af 721
# ONT-MCO
# 691 af 721
# JAX-LAS
# 692 af 721
# MCO-ONT
# 693 af 721
# LAS-JAX
# 694 af 721
# MCO-MDT
# 695 af 721
# MDT-MCO
# 696 af 721
# SNA-SAT
# 697 af 721
# SAT-SNA
# 698 af 721
# PRC-DEN
# 699 af 721
# DEN-EAR
# 700 af 721
# EAR-DEN
# 701 af 721
# AVL-MCO
# 702 af 721
# MCO-AVL
# 703 af 721
# BUR-BOS
# 704 af 721
# BOS-BUR
# 705 af 721
# HOU-SDF
# 706 af 721
# SDF-HOU
# 707 af 721
# JFK-SNA
# 708 af 721
# SNA-JFK
# 709 af 721
# ORD-SHD
# 710 af 721
# SHD-ORD
# 711 af 721
# DRT-DFW
# 712 af 721
# DFW-DRT
# 713 af 721
# OKC-DCA
# 714 af 721
# BUR-HOU
# 715 af 721
# BUR-MDW
# 716 af 721
# DCA-OKC
# 717 af 721
# HOU-BUR
# 718 af 721
# MDW-BUR
# 719 af 721
# CYS-DFW
# 720 af 721
# DFW-CYS
# 721 af 721

# %% [markdown]
# ### THOR

# %%
# Indsæt driverpath (skal vise lokal path)
prices2=skyscannerscraper(data5['Origin'],data5['Dest'],190527,save='prices_3000_3999', driverpath='C:/Users/thorn/OneDrive/Dokumenter/GitHub/TSDS-gruppe-2019/Exam/geckodriver_win64', direct='true')
