# %%
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import re
import os
import time

# %%
data=pd.read_pickle('scrape_data.pkl')
data1=data[0:200] # FÆRDIG
data2=data[200:1000]      # CHRISTIAN
data3=data[1000:2000]     # CHRISTIAN
data4=data[2000:3000]
data5a=data[3000:3240]    # FÆRDIG
data5b=data[3240:4000]    # THOR
data6=data[4000:]         # MORTEN

# %%
def skyscannerscraper(dep,arr,date, save, driverpath, direct='true'):
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # save: filename
    # driverpath: complete path to driver
    # direct: indicates whether direct flight is preferred
    save2=save+".pkl"
    
    driver = webdriver.Firefox(executable_path=driverpath)
    driver.implicitly_wait(7)
    wait = WebDriverWait(driver, 8)
    urlbase = 'https://www.skyscanner.com/transport/flights/'
    urlpas='/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    data = []
    count=0
    for depa,arri in zip(dep,arr):
        count+=1
        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend

        driver.get(url)
        time.sleep(6) 
        try:
            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
            r=price[0]
            if r==' ':
                del r
                #print('r=0')
                raise ValueError
            elif r=='Ingen':
                #print('r=0')
                raise ValueError
                del r
            else:
                data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                del r
                del price
            
        except (TimeoutException,StaleElementReferenceException,BaseException):
            try:
                WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
                #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                r=price[0]
                if r==' ':
                    del r
                    #print('r=0')
                    raise ValueError
                elif r=='Ingen':
                    del r
                    #print('r=0')
                    raise ValueError
                else:
                    data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                    del r
                    del price
                    


            except (TimeoutException,StaleElementReferenceException,BaseException):
                try:
                    time.sleep(3)
                    #print('Round2')
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                    #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                    label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                    r=price[0]
                    if r==' ':
                        del r
                        #print('r=0')
                        raise ValueError
                    elif r=='Ingen':
                        #print('r=0')
                        raise ValueError
                        del r
                    else:
                        data.append({
                            "price": price[0],
                            "origin": str(depa),
                            "destination": str(arri),
                            "label": label[0],
                            "day":0
                                })
                        del r
                        del price

                except (TimeoutException,StaleElementReferenceException,BaseException):
                        try:
                            WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                            wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                            r=price[0]
                            if r==' ':
                                del r
                                #print('r=0')
                                raise ValueError
                            elif r=='Ingen':
                                del r
                                #print('r=0')
                                raise ValueError
                            else:
                                data.append({
                                "price": price[0],
                                "origin": str(depa),
                                "destination": str(arri),
                                "label": label[0],
                                "day":0
                                    })
                                del r
                                del price

                        except (TimeoutException,StaleElementReferenceException,BaseException):
                            try:
                                #print('indirect')
                                wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))

                                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                                data.append({
                                        "price": price[1],
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": label[1],
                                        "day":0,
                                        "alternative": price[0]
                                            })
                                del price


                            except (TimeoutException,StaleElementReferenceException,BaseException):

                                print("Not working for "+str(url))


                                data.append({
                                        "price": '-',
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": '-',
                                        "day":0
                                            })
                    
        print(str(depa)+"-"+str(arri))
        
        print(str(count)+" af " +str(len(dep.index)))
        time.sleep(2)
        price_data = pd.DataFrame(data)
        if count%20==0:
            price_data.to_pickle(save2)
        if count%200==0:
            time.sleep(300)
    price_data.to_pickle(save2)
    driver.close()
    
    
    
    return price_data

# %%
# Indsæt driverpath (skal vise lokal path)

prices2=skyscannerscraper(data2['Origin'],data2['Dest'],190527,save='prices_200_1000', driverpath='/Users/Christian/Dropbox/Universitet/TSODAS/TSDS-gruppe-2019/Exam/geckodriver', direct='true')
# Out:
# BWI-LAX
# 1 af 2
# Round2
# BWI-LIT
# 2 af 2

# %% [markdown]
# ### MORTEN

# %%
# Indsæt driverpath (skal vise lokal path)
prices2=skyscannerscraper(data6['Origin'],data6['Dest'],190527,save='prices_4000_', driverpath='', direct='true')

# %% [markdown]
# ### THOR

# %%
# Indsæt driverpath (skal vise lokal path)
prices2=skyscannerscraper(data5['Origin'],data5['Dest'],190527,save='prices_3000_3999', driverpath='C:/Users/thorn/OneDrive/Dokumenter/GitHub/TSDS-gruppe-2019/Exam/geckodriver_win64', direct='true')
prices2.to_pickle('prices_3000_3999.pkl')
# Out:
# ILG-ATL
# 1 af 1000
# CVG-BTR
# 2 af 1000
# DCA-JAN
# 3 af 1000
# ERI-ATL
# 4 af 1000
# JAN-DCA
# 5 af 1000
# ABY-ATL
# 6 af 1000
# CVG-SHV
# 7 af 1000
# MGM-CVG
# 8 af 1000
# ATL-ACY
# 9 af 1000
# ACY-ATL
# 10 af 1000
# CVG-MGM
# 11 af 1000
# ATL-XNA
# 12 af 1000
# FNT-ATL
# 13 af 1000
# ATL-SGF
# 14 af 1000
# ATL-ABE
# 15 af 1000
# VLD-ATL
# 16 af 1000
# ATL-ALB
# 17 af 1000
# ATL-ISO
# 18 af 1000
# ISO-ATL
# 19 af 1000
# CVG-CAE
# 20 af 1000
# CAE-CVG
# 21 af 1000
# ATL-MEI
# 22 af 1000
# ATL-AVP
# 23 af 1000
# ATL-OAJ
# 24 af 1000
# ATL-TRI
# 25 af 1000
# ATL-MLU
# 26 af 1000
# ATL-TUP
# 27 af 1000
# ATL-APF
# 28 af 1000
# HPN-ATL
# 29 af 1000
# ATL-BGR
# 30 af 1000
# ATL-AEX
# 31 af 1000
# ATL-FLO
# 32 af 1000
# ATL-FNT
# 33 af 1000
# ILM-ATL
# 34 af 1000
# ATL-CID
# 35 af 1000
# FAY-ATL
# 36 af 1000
# FLO-ATL
# 37 af 1000
# ATL-MLI
# 38 af 1000
# ALB-ATL
# 39 af 1000
# ATL-MFE
# 40 af 1000
# ATL-ERI
# 41 af 1000
# ATL-VLD
# 42 af 1000
# LFT-ATL
# 43 af 1000
# Not working for https://www.skyscanner.com/transport/flights/DCA/MLB/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DCA-MLB
# 44 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MLB/DCA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MLB-DCA
# 45 af 1000
# OAJ-ATL
# 46 af 1000
# ATL-AZO
# 47 af 1000
# EYW-ATL
# 48 af 1000
# TUP-ATL
# 49 af 1000
# CID-ATL
# 50 af 1000
# ATL-BGM
# 51 af 1000
# ATL-TOL
# 52 af 1000
# ATL-BTV
# 53 af 1000
# ATL-ILG
# 54 af 1000
# ATL-GRK
# 55 af 1000
# MLI-ATL
# 56 af 1000
# ATL-DSM
# 57 af 1000
# BTV-ATL
# 58 af 1000
# DSM-ATL
# 59 af 1000
# ATL-CRP
# 60 af 1000
# ATL-LFT
# 61 af 1000
# ATL-ISP
# 62 af 1000
# GRK-ATL
# 63 af 1000
# BGM-ATL
# 64 af 1000
# FWA-ATL
# 65 af 1000
# BTR-CVG
# 66 af 1000
# AZO-ATL
# 67 af 1000
# PFN-TLH
# 68 af 1000
# ATL-FSD
# 69 af 1000
# ATL-BQN
# 70 af 1000
# SHV-CVG
# 71 af 1000
# LGA-CAE
# 72 af 1000
# ATL-PSE
# 73 af 1000
# CVG-SBN
# 74 af 1000
# DEN-DAY
# 75 af 1000
# DEN-CAK
# 76 af 1000
# CAK-DEN
# 77 af 1000
# DEN-RSW
# 78 af 1000
# RSW-DEN
# 79 af 1000
# DAY-DEN
# 80 af 1000
# ATL-BMI
# 81 af 1000
# BMI-ATL
# 82 af 1000
# BOS-CAK
# 83 af 1000
# BOS-ROC
# 84 af 1000
# BWI-DAY
# 85 af 1000
# BWI-ROC
# 86 af 1000
# BWI-SRQ
# 87 af 1000
# CAK-BOS
# 88 af 1000
# Not working for https://www.skyscanner.com/transport/flights/CAK/LGA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CAK-LGA
# 89 af 1000
# CAK-MCO
# 90 af 1000
# CAK-RSW
# 91 af 1000
# CAK-TPA
# 92 af 1000
# CLT-MDW
# 93 af 1000
# DAY-BWI
# 94 af 1000
# DAY-MCO
# 95 af 1000
# DAY-TPA
# 96 af 1000
# DFW-MCO
# 97 af 1000
# DFW-MDW
# 98 af 1000
# DTW-FLL
# 99 af 1000
# DTW-RSW
# 100 af 1000
# Not working for https://www.skyscanner.com/transport/flights/DTW/SRQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DTW-SRQ
# 101 af 1000
# DTW-TPA
# 102 af 1000
# FLL-DTW
# 103 af 1000
# FLL-GPT
# 104 af 1000
# FLL-HPN
# 105 af 1000
# FLL-IND
# 106 af 1000
# FLL-PHF
# 107 af 1000
# FLL-ROC
# 108 af 1000
# FNT-MCO
# 109 af 1000
# FNT-RSW
# 110 af 1000
# FNT-TPA
# 111 af 1000
# GPT-FLL
# 112 af 1000
# GPT-TPA
# 113 af 1000
# HPN-FLL
# 114 af 1000
# HPN-MCO
# 115 af 1000
# HPN-PBI
# 116 af 1000
# HPN-RSW
# 117 af 1000
# HPN-TPA
# 118 af 1000
# IND-FLL
# 119 af 1000
# IND-MIA
# 120 af 1000
# IND-RSW
# 121 af 1000
# IND-SRQ
# 122 af 1000
# LGA-CAK
# 123 af 1000
# LGA-PHF
# 124 af 1000
# MCO-CAK
# 125 af 1000
# MCO-DAY
# 126 af 1000
# MCO-DFW
# 127 af 1000
# MCO-FNT
# 128 af 1000
# MCO-HPN
# 129 af 1000
# MCO-MKE
# 130 af 1000
# MCO-MLI
# 131 af 1000
# MCO-MSP
# 132 af 1000
# MCO-PHF
# 133 af 1000
# MCO-ROC
# 134 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MDW/CLT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-CLT
# 135 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MDW/DFW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-DFW
# 136 af 1000
# MDW-MSP
# 137 af 1000
# MDW-SRQ
# 138 af 1000
# MIA-IND
# 139 af 1000
# MKE-MCO
# 140 af 1000
# MKE-TPA
# 141 af 1000
# MLI-MCO
# 142 af 1000
# MSP-MCO
# 143 af 1000
# MSP-MDW
# 144 af 1000
# PBI-HPN
# 145 af 1000
# PHF-FLL
# 146 af 1000
# PHF-LGA
# 147 af 1000
# PHF-MCO
# 148 af 1000
# ROC-BOS
# 149 af 1000
# ROC-BWI
# 150 af 1000
# ROC-FLL
# 151 af 1000
# ROC-MCO
# 152 af 1000
# ROC-TPA
# 153 af 1000
# RSW-CAK
# 154 af 1000
# RSW-DTW
# 155 af 1000
# Not working for https://www.skyscanner.com/transport/flights/RSW/FNT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RSW-FNT
# 156 af 1000
# RSW-HPN
# 157 af 1000
# RSW-IND
# 158 af 1000
# SRQ-BWI
# 159 af 1000
# Not working for https://www.skyscanner.com/transport/flights/SRQ/DTW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SRQ-DTW
# 160 af 1000
# SRQ-IND
# 161 af 1000
# SRQ-MDW
# 162 af 1000
# TPA-CAK
# 163 af 1000
# TPA-DAY
# 164 af 1000
# TPA-DTW
# 165 af 1000
# TPA-FNT
# 166 af 1000
# TPA-GPT
# 167 af 1000
# TPA-HPN
# 168 af 1000
# TPA-MKE
# 169 af 1000
# TPA-ROC
# 170 af 1000
# Not working for https://www.skyscanner.com/transport/flights/BMI/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BMI-MCO
# 171 af 1000
# IND-PBI
# 172 af 1000
# Not working for https://www.skyscanner.com/transport/flights/MCO/BMI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCO-BMI
# 173 af 1000
# PBI-IND
# 174 af 1000
# CAK-FLL
# 175 af 1000
# FLL-CAK
# 176 af 1000
# MCO-RIC
# 177 af 1000
# RIC-MCO
# 178 af 1000
# ATL-SWF
# 179 af 1000
# FLL-SWF
# 180 af 1000
# MCO-SWF
# 181 af 1000
# MDW-MIA
# 182 af 1000
# MIA-MDW
# 183 af 1000
# Not working for https://www.skyscanner.com/transport/flights/SWF/ATL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# SWF-ATL
# 184 af 1000
# SWF-FLL
# 185 af 1000
# SWF-MCO
# 186 af 1000
# SWF-TPA
# 187 af 1000
# TPA-SWF
# 188 af 1000
# LAS-HNL
# 189 af 1000
# HNL-LAS
# 190 af 1000
# SMF-HNL
# 191 af 1000
# HNL-SMF
# 192 af 1000
# PDX-HNL
# 193 af 1000
# HNL-PDX
# 194 af 1000
# SEA-OGG
# 195 af 1000
# OGG-SEA
# 196 af 1000
# SAN-OGG
# 197 af 1000
# OGG-SAN
# 198 af 1000
# PDX-OGG
# 199 af 1000
# OGG-PDX
# 200 af 1000
# SJC-HNL
# 201 af 1000
# HNL-SJC
# 202 af 1000
# ITO-OGG
# 203 af 1000
# OGG-ITO
# 204 af 1000
# KOA-OGG
# 205 af 1000
# LIH-OGG
# 206 af 1000
# XNA-LAX
# 207 af 1000
# LAX-XNA
# 208 af 1000
# TYR-DFW
# 209 af 1000
# DFW-TYR
# 210 af 1000
# GRK-DFW
# 211 af 1000
# DFW-GRK
# 212 af 1000
# AEX-DFW
# 213 af 1000
# DFW-AEX
# 214 af 1000
# DFW-CLL
# 215 af 1000
# ABI-DFW
# 216 af 1000
# DFW-ABI
# 217 af 1000
# SPS-DFW
# 218 af 1000
# DFW-TXK
# 219 af 1000
# CLL-DFW
# 220 af 1000
# DFW-LFT
# 221 af 1000
# LAW-DFW
# 222 af 1000
# DFW-ACT
# 223 af 1000
# GGG-DFW
# 224 af 1000
# DFW-LAW
# 225 af 1000
# DFW-SJT
# 226 af 1000
# SJT-DFW
# 227 af 1000
# LFT-DFW
# 228 af 1000
# SHV-DFW
# 229 af 1000
# DFW-SHV
# 230 af 1000
# ACT-DFW
# 231 af 1000
# DFW-GGG
# 232 af 1000
# DFW-SPS
# 233 af 1000
# MLU-DFW
# 234 af 1000
# DFW-MLU
# 235 af 1000
# TXK-DFW
# 236 af 1000
# MOB-DFW
# 237 af 1000
# DFW-MOB
# 238 af 1000
# AMA-DFW
# 239 af 1000
# DFW-AMA
# 240 af 1000
# VPS-DFW
# 241 af 1000
# DFW-VPS
# 242 af 1000
# LIT-DFW
# 243 af 1000
# DFW-LIT
# 244 af 1000
# PIT-DFW
# 245 af 1000
# DFW-PIT
# 246 af 1000
# DFW-LRD
# 247 af 1000
# CID-DFW
# 248 af 1000
# GSO-DFW
# 249 af 1000
# DFW-GSO
# 250 af 1000
# GPT-DFW
# 251 af 1000
# DFW-SGF
# 252 af 1000
# SGF-DFW
# 253 af 1000
# DFW-GPT
# 254 af 1000
# MSN-DFW
# 255 af 1000
# DFW-TYS
# 256 af 1000

# %%
prices2.to_pickle('prices_3000_3999.pkl')
