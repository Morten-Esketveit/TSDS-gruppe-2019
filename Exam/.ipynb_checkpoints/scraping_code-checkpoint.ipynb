# %%
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import re
import os
import time

# %%
data=pd.read_pickle('scrape_data.pkl')

# %%
data.count()
# Out:
# Year             5342
# Month            5342
# DayofMonth       5342
# DayOfWeek        5342
# DepTime          5235
# UniqueCarrier    5342
# Origin           5342
# Dest             5342
# Distance         5342
# Journey          5342
# dtype: int64

# %%
data1=data[0:1000]
data2=data[1000:2000]
data3=data[2000:3000]
data4=data[3000:4000]
data5=data[4000:]

# %%
def skyscannerscraper(dep,arr,date, direct='true'):
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # direct: indicates whether direct flight is preferred
    driver = webdriver.Firefox(executable_path='/Users/Christian/Dropbox/Universitet/TSODAS/test/geckodriver')
    driver.implicitly_wait(7)
    wait = WebDriverWait(driver, 8)
    urlbase = 'https://www.skyscanner.com/transport/flights/'
    urlpas='/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    data = []
    count=0
    for depa,arri in zip(dep,arr):
        count+=0
        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend

        driver.get(url)
        time.sleep(6) 
        try:
            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
            r=price[0]
            if r==' ':
                del r
                print('r=0')
                raise ValueError
            elif r=='Ingen':
                print('r=0')
                raise ValueError
                del r
            else:
                data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                del r
                del price
            
        except (TimeoutException,StaleElementReferenceException,BaseException):
            try:
                WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
                #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                r=price[0]
                if r==' ':
                    del r
                    print('r=0')
                    raise ValueError
                elif r=='Ingen':
                    del r
                    print('r=0')
                    raise ValueError
                else:
                    data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                    del r
                    del price
                    


            except (TimeoutException,StaleElementReferenceException,BaseException):
                try:
                    time.sleep(3)
                    print('Round2')
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                    #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                    label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                    r=price[0]
                    if r==' ':
                        del r
                        print('r=0')
                        raise ValueError
                    elif r=='Ingen':
                        print('r=0')
                        raise ValueError
                        del r
                    else:
                        data.append({
                            "price": price[0],
                            "origin": str(depa),
                            "destination": str(arri),
                            "label": label[0],
                            "day":0
                                })
                        del r
                        del price

                except (TimeoutException,StaleElementReferenceException,BaseException):
                        try:
                            WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                            wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                            r=price[0]
                            if r==' ':
                                del r
                                print('r=0')
                                raise ValueError
                            elif r=='Ingen':
                                del r
                                print('r=0')
                                raise ValueError
                            else:
                                data.append({
                                "price": price[0],
                                "origin": str(depa),
                                "destination": str(arri),
                                "label": label[0],
                                "day":0
                                    })
                                del r
                                del price

                        except (TimeoutException,StaleElementReferenceException,BaseException):
                            try:
                                print('indirect')
                                wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))

                                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                                data.append({
                                        "price": price[1],
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": label[1],
                                        "day":0,
                                        "alternative": price[0]
                                            })
                                del price


                            except (TimeoutException,StaleElementReferenceException,BaseException):

                                print("Not working for "+str(url))


                                data.append({
                                        "price": '-',
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": '-',
                                        "day":0
                                            })
                    
        print(str(depa)+"-"+str(arri))
        time.sleep(2)
    driver.close()
              
    price_data = pd.DataFrame(data)                                            
    return price_data

# %%
start = time.time()
prices1=skyscannerscraper(data1['Origin'],data1['Dest'],190527, direct='true')
end = time.time()
print(end-start)
prices1.to_pickle('del1.pkl')
# Out:
# r=0
# Round2
# r=0
# indirect
# SMF-ONT
# Round2
# SMF-PDX
# Round2
# SMF-PHX
# Round2
# SMF-SAN
# Round2
# SMF-SEA
# r=0
# Round2
# r=0
# indirect
# SMF-SNA
# SNA-LAS
# r=0
# Round2
# r=0
# indirect
# SNA-MDW
# SNA-OAK
# SNA-PHX
# SNA-SJC
# Round2
# r=0
# indirect
# SNA-SMF
# Round2
# r=0
# indirect
# STL-ABQ
# r=0
# Round2
# r=0
# indirect
# STL-BHM
# r=0
# Round2
# r=0
# indirect
# STL-BWI
# Round2
# r=0
# indirect
# STL-CLE
# Round2
# r=0
# indirect
# STL-CMH
# r=0
# Round2
# r=0
# indirect
# STL-DAL
# STL-DTW
# Round2
# indirect
# STL-FLL
# r=0
# Round2
# r=0
# indirect
# STL-HOU
# Round2
# STL-LAS
# Round2
# STL-LAX
# STL-LIT
# Round2
# STL-MCI
# STL-MCO
# r=0
# Round2
# STL-MDW
# r=0
# Round2
# r=0
# indirect
# STL-OKC
# Round2
# STL-OMA
# r=0
# Round2
# STL-PHX
# Round2
# STL-SDF
# Round2
# STL-SLC
# Round2
# r=0
# indirect
# STL-TPA
# STL-TUL
# r=0
# Round2
# r=0
# indirect
# TPA-ABQ
# r=0
# Round2
# r=0
# indirect
# TPA-ALB
# r=0
# Round2
# r=0
# indirect
# TPA-AUS
# r=0
# Round2
# TPA-BDL
# Round2
# r=0
# indirect
# TPA-BHM
# r=0
# Round2
# r=0
# indirect
# TPA-BNA
# r=0
# Round2
# r=0
# indirect
# TPA-BUF
# Round2
# TPA-BWI
# Round2
# r=0
# indirect
# TPA-CMH
# Round2
# TPA-FLL
# r=0
# Round2
# r=0
# indirect
# TPA-HOU
# TPA-IAD
# r=0
# Round2
# r=0
# indirect
# TPA-IND
# r=0
# Round2
# r=0
# indirect
# TPA-ISP
# TPA-JAX
# TPA-LAS
# Round2
# r=0
# indirect
# TPA-MCI
# r=0
# Round2
# r=0
# indirect
# TPA-MDW
# r=0
# Round2
# r=0
# indirect
# TPA-MHT
# Round2
# TPA-MSY
# TPA-PBI
# TPA-PHL
# r=0
# Round2
# TPA-PHX
# r=0
# Round2
# r=0
# indirect
# TPA-PIT
# r=0
# Round2
# r=0
# indirect
# TPA-PVD
# TPA-RDU
# Round2
# r=0
# indirect
# TPA-SAT
# r=0
# Round2
# r=0
# indirect
# TPA-SDF
# r=0
# Round2
# r=0
# indirect
# TPA-STL
# r=0
# Round2
# r=0
# indirect
# TUL-DAL
# r=0
# Round2
# r=0
# indirect
# TUL-HOU
# r=0
# Round2
# TUL-LAS
# r=0
# Round2
# r=0
# indirect
# TUL-MCI
# r=0
# Round2
# r=0
# indirect
# TUL-PHX
# r=0
# Round2
# TUL-STL
# Round2
# indirect
# TUS-ABQ
# r=0
# Round2
# TUS-LAS
# TUS-LAX
# r=0
# Round2
# r=0
# indirect
# TUS-MDW
# r=0
# Round2
# r=0
# indirect
# TUS-SAN
# r=0
# Round2
# r=0
# indirect
# ABQ-AMA
# r=0
# Round2
# r=0
# indirect
# ABQ-BWI
# r=0
# Round2
# r=0
# indirect
# ABQ-DAL
# r=0
# Round2
# r=0
# indirect
# ABQ-ELP
# r=0
# Round2
# r=0
# indirect
# ABQ-HOU
# r=0
# Round2
# ABQ-LAS
# r=0
# Round2
# ABQ-LAX
# r=0
# Round2
# r=0
# indirect
# ABQ-LBB
# r=0
# Round2
# r=0
# indirect
# ABQ-MAF
# r=0
# Round2
# r=0
# indirect
# ABQ-MCI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ABQ/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ABQ-MCO
# r=0
# Round2
# r=0
# indirect
# ABQ-MDW
# r=0
# Round2
# r=0
# indirect
# ABQ-OAK
# r=0
# Round2
# ABQ-PDX
# r=0
# Round2
# ABQ-PHX
# r=0
# Round2
# ABQ-SAN
# r=0
# Round2
# ABQ-SEA
# r=0
# Round2
# ABQ-SLC
# r=0
# Round2
# r=0
# indirect
# ABQ-STL
# r=0
# Round2
# r=0
# indirect
# ABQ-TPA
# r=0
# Round2
# ABQ-TUS
# r=0
# Round2
# r=0
# indirect
# ALB-BWI
# r=0
# Round2
# r=0
# indirect
# ALB-LAS
# r=0
# Round2
# ALB-MCO
# r=0
# Round2
# r=0
# indirect
# ALB-MDW
# r=0
# Round2
# r=0
# indirect
# ALB-TPA
# r=0
# Round2
# r=0
# indirect
# AMA-ABQ
# r=0
# Round2
# r=0
# indirect
# AMA-DAL
# r=0
# Round2
# r=0
# indirect
# AMA-LAS
# r=0
# Round2
# r=0
# indirect
# AUS-BNA
# r=0
# Round2
# AUS-BWI
# r=0
# Round2
# AUS-DAL
# r=0
# Round2
# r=0
# indirect
# AUS-ELP
# r=0
# Round2
# r=0
# indirect
# AUS-HOU
# r=0
# Round2
# r=0
# indirect
# AUS-HRL
# r=0
# Round2
# AUS-LAS
# AUS-LAX
# r=0
# Round2
# r=0
# indirect
# AUS-LBB
# r=0
# Round2
# r=0
# indirect
# AUS-MAF
# AUS-MCO
# r=0
# Round2
# r=0
# indirect
# AUS-MDW
# r=0
# Round2
# AUS-PHX
# AUS-SAN
# r=0
# Round2
# r=0
# indirect
# AUS-TPA
# r=0
# Round2
# r=0
# indirect
# BDL-BNA
# r=0
# Round2
# r=0
# indirect
# BDL-BWI
# r=0
# Round2
# r=0
# indirect
# BDL-LAS
# BDL-MCO
# r=0
# Round2
# r=0
# indirect
# BDL-MDW
# r=0
# Round2
# BDL-PHL
# r=0
# Round2
# BDL-TPA
# r=0
# Round2
# r=0
# indirect
# BHM-BNA
# r=0
# Round2
# r=0
# indirect
# BHM-BWI
# r=0
# Round2
# r=0
# indirect
# BHM-HOU
# r=0
# Round2
# r=0
# indirect
# BHM-JAX
# r=0
# Round2
# r=0
# indirect
# BHM-LAS
# r=0
# Round2
# r=0
# indirect
# BHM-MCO
# r=0
# Round2
# r=0
# indirect
# BHM-MDW
# r=0
# Round2
# r=0
# indirect
# BHM-PHX
# r=0
# Round2
# r=0
# indirect
# BHM-SDF
# r=0
# Round2
# r=0
# indirect
# BHM-STL
# r=0
# Round2
# r=0
# indirect
# BHM-TPA
# r=0
# Round2
# r=0
# indirect
# BNA-AUS
# r=0
# Round2
# r=0
# indirect
# BNA-BDL
# r=0
# Round2
# r=0
# indirect
# BNA-BHM
# r=0
# Round2
# r=0
# indirect
# BNA-BWI
# r=0
# Round2
# r=0
# indirect
# BNA-CLE
# r=0
# Round2
# BNA-CMH
# BNA-DEN
# r=0
# Round2
# BNA-DTW
# r=0
# Round2
# r=0
# indirect
# BNA-FLL
# r=0
# Round2
# r=0
# indirect
# BNA-HOU
# r=0
# Round2
# r=0
# indirect
# BNA-JAX
# BNA-LAS
# BNA-LAX
# r=0
# Round2
# r=0
# indirect
# BNA-MCI
# BNA-MCO
# r=0
# Round2
# r=0
# indirect
# BNA-MDW
# r=0
# Round2
# r=0
# indirect
# BNA-MSY
# r=0
# Round2
# r=0
# indirect
# BNA-OAK
# r=0
# Round2
# r=0
# indirect
# BNA-ONT
# BNA-PHL
# r=0
# Round2
# r=0
# indirect
# BNA-PHX
# r=0
# Round2
# BNA-PVD
# r=0
# Round2
# BNA-RDU
# r=0
# Round2
# r=0
# indirect
# BNA-SAN
# r=0
# Round2
# r=0
# indirect
# BNA-SAT
# BNA-SEA
# r=0
# Round2
# r=0
# indirect
# BNA-TPA
# r=0
# Round2
# BOI-GEG
# r=0
# Round2
# r=0
# indirect
# BOI-LAS
# r=0
# Round2
# r=0
# indirect
# BOI-OAK
# r=0
# Round2
# BOI-PDX
# r=0
# Round2
# BOI-PHX
# r=0
# Round2
# BOI-RNO
# r=0
# Round2
# BOI-SEA
# r=0
# Round2
# BOI-SLC
# r=0
# Round2
# r=0
# indirect
# BUF-BWI
# r=0
# Round2
# r=0
# indirect
# BUF-LAS
# BUF-MCO
# r=0
# Round2
# r=0
# indirect
# BUF-MDW
# r=0
# Round2
# r=0
# indirect
# BUF-PHX
# r=0
# Round2
# r=0
# indirect
# BUF-TPA
# r=0
# Round2
# BUR-LAS
# r=0
# Round2
# r=0
# indirect
# BUR-OAK
# r=0
# Round2
# BUR-PHX
# BUR-SJC
# r=0
# Round2
# r=0
# indirect
# BUR-SMF
# r=0
# Round2
# r=0
# indirect
# BWI-ABQ
# r=0
# Round2
# r=0
# indirect
# BWI-ALB
# r=0
# Round2
# BWI-AUS
# r=0
# Round2
# r=0
# indirect
# BWI-BDL
# r=0
# Round2
# r=0
# indirect
# BWI-BHM
# r=0
# Round2
# r=0
# indirect
# BWI-BNA
# r=0
# Round2
# r=0
# indirect
# BWI-BUF
# r=0
# Round2
# r=0
# indirect
# BWI-CLE
# r=0
# Round2
# r=0
# indirect
# BWI-CMH
# BWI-DEN
# BWI-DTW
# BWI-FLL
# r=0
# Round2
# r=0
# indirect
# BWI-HOU
# r=0
# Round2
# r=0
# indirect
# BWI-IND
# r=0
# Round2
# BWI-ISP
# r=0
# Round2
# r=0
# indirect
# BWI-JAN
# r=0
# Round2
# BWI-JAX
# BWI-LAS
# BWI-LAX
# r=0
# Round2
# r=0
# indirect
# BWI-LIT
# r=0
# Round2
# r=0
# indirect
# BWI-MCI
# BWI-MCO
# r=0
# Round2
# r=0
# indirect
# BWI-MDW
# r=0
# Round2
# r=0
# indirect
# BWI-MHT
# r=0
# Round2
# BWI-MSY
# r=0
# Round2
# r=0
# indirect
# BWI-OAK
# r=0
# Round2
# r=0
# indirect
# BWI-ORF
# r=0
# Round2
# r=0
# indirect
# BWI-PBI
# r=0
# Round2
# BWI-PHX
# r=0
# Round2
# r=0
# indirect
# Not working for https://www.skyscanner.com/transport/flights/BWI/PVD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BWI-PVD
# r=0
# Round2
# BWI-RDU
# r=0
# Round2
# r=0
# indirect
# BWI-RSW
# r=0
# Round2
# BWI-SAN
# r=0
# Round2
# r=0
# indirect
# BWI-SAT
# r=0
# Round2
# r=0
# indirect
# BWI-SDF
# r=0
# Round2
# BWI-SLC
# r=0
# Round2
# r=0
# indirect
# BWI-STL
# BWI-TPA
# r=0
# Round2
# r=0
# indirect
# CLE-BNA
# r=0
# Round2
# r=0
# indirect
# CLE-BWI
# r=0
# Round2
# CLE-LAS
# r=0
# Round2
# CLE-MDW
# r=0
# Round2
# r=0
# indirect
# Not working for https://www.skyscanner.com/transport/flights/CLE/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CLE-PHX
# r=0
# Round2
# r=0
# indirect
# CLE-STL
# r=0
# Round2
# CMH-BNA
# r=0
# Round2
# r=0
# indirect
# CMH-BWI
# r=0
# Round2
# CMH-LAS
# CMH-MCO
# r=0
# Round2
# r=0
# indirect
# CMH-MDW
# r=0
# Round2
# CMH-PHL
# r=0
# Round2
# CMH-PHX
# r=0
# Round2
# r=0
# indirect
# CMH-STL
# r=0
# Round2
# r=0
# indirect
# CMH-TPA
# r=0
# Round2
# r=0
# indirect
# CRP-HOU
# r=0
# Round2
# r=0
# indirect
# DAL-ABQ
# r=0
# Round2
# r=0
# indirect
# DAL-AMA
# r=0
# Round2
# DAL-AUS
# r=0
# Round2
# r=0
# indirect
# DAL-ELP
# r=0
# Round2
# r=0
# indirect
# DAL-HOU
# r=0
# Round2
# r=0
# indirect
# DAL-LBB
# r=0
# Round2
# r=0
# indirect
# DAL-LIT
# r=0
# Round2
# r=0
# indirect
# DAL-MAF
# r=0
# Round2
# r=0
# indirect
# DAL-MCI
# r=0
# Round2
# r=0
# indirect
# DAL-MSY
# r=0
# Round2
# r=0
# indirect
# DAL-OKC
# r=0
# Round2
# r=0
# indirect
# DAL-SAT
# r=0
# Round2
# r=0
# indirect
# DAL-STL
# r=0
# Round2
# r=0
# indirect
# DAL-TUL
# DEN-BNA
# DEN-BWI
# r=0
# Round2
# r=0
# indirect
# DEN-HOU
# DEN-LAS
# DEN-MCI
# DEN-MCO
# r=0
# Round2
# r=0
# indirect
# DEN-MDW
# DEN-PHX
# DEN-SLC
# r=0
# Round2
# DTW-BNA
# DTW-BWI
# DTW-MCO
# r=0
# Round2
# DTW-MDW
# r=0
# Round2
# DTW-PHX
# r=0
# Round2
# DTW-STL
# r=0
# Round2
# r=0
# indirect
# ELP-ABQ
# r=0
# Round2
# r=0
# indirect
# ELP-AUS
# r=0
# Round2
# r=0
# indirect
# ELP-DAL
# r=0
# Round2
# r=0
# indirect
# ELP-HOU
# r=0
# Round2
# r=0
# indirect
# ELP-LAS
# r=0
# Round2
# ELP-LAX
# r=0
# Round2
# r=0
# indirect
# ELP-LBB
# r=0
# Round2
# r=0
# indirect
# ELP-MAF
# r=0
# Round2
# ELP-PHX
# r=0
# Round2
# ELP-SAN
# r=0
# Round2
# r=0
# indirect
# ELP-SAT
# r=0
# Round2
# r=0
# indirect
# FLL-BNA
# FLL-BWI
# r=0
# Round2
# r=0
# indirect
# FLL-HOU
# FLL-ISP
# r=0
# Round2
# FLL-JAX
# FLL-MCO
# r=0
# Round2
# r=0
# indirect
# FLL-MDW
# FLL-MSY
# FLL-PHL
# r=0
# Round2
# r=0
# indirect
# FLL-STL
# FLL-TPA
# r=0
# Round2
# GEG-BOI
# r=0
# Round2
# r=0
# indirect
# GEG-LAS
# r=0
# Round2
# r=0
# indirect
# GEG-OAK
# r=0
# Round2
# GEG-PDX
# r=0
# Round2
# indirect
# GEG-SEA
# r=0
# Round2
# GEG-SLC
# r=0
# Round2
# r=0
# indirect
# HOU-ABQ
# r=0
# Round2
# r=0
# indirect
# HOU-AUS
# r=0
# Round2
# r=0
# indirect
# HOU-BHM
# r=0
# Round2
# r=0
# indirect
# HOU-BNA
# r=0
# Round2
# r=0
# indirect
# HOU-BWI
# r=0
# Round2
# r=0
# indirect
# HOU-CRP
# r=0
# Round2
# r=0
# indirect
# HOU-DAL
# r=0
# Round2
# r=0
# indirect
# HOU-DEN
# r=0
# Round2
# r=0
# indirect
# HOU-ELP
# r=0
# Round2
# r=0
# indirect
# HOU-FLL
# r=0
# Round2
# r=0
# indirect
# HOU-HRL
# r=0
# Round2
# r=0
# indirect
# HOU-JAN
# r=0
# Round2
# r=0
# indirect
# HOU-JAX
# r=0
# Round2
# r=0
# indirect
# HOU-LAS
# r=0
# Round2
# r=0
# indirect
# HOU-LAX
# r=0
# Round2
# r=0
# indirect
# HOU-LIT
# r=0
# Round2
# r=0
# indirect
# HOU-MAF
# r=0
# Round2
# r=0
# indirect
# HOU-MCO
# r=0
# Round2
# r=0
# indirect
# HOU-MDW
# r=0
# Round2
# r=0
# indirect
# HOU-MSY
# r=0
# Round2
# r=0
# indirect
# HOU-OAK
# r=0
# Round2
# r=0
# indirect
# HOU-OKC
# r=0
# Round2
# r=0
# indirect
# HOU-PHL
# r=0
# Round2
# r=0
# indirect
# HOU-PHX
# r=0
# Round2
# HOU-SAT
# r=0
# Round2
# r=0
# indirect
# HOU-STL
# r=0
# Round2
# r=0
# indirect
# HOU-TPA
# r=0
# Round2
# r=0
# indirect
# HOU-TUL
# r=0
# Round2
# r=0
# indirect
# HRL-AUS
# r=0
# Round2
# r=0
# indirect
# HRL-HOU
# r=0
# Round2
# r=0
# indirect
# HRL-SAT
# r=0
# Round2
# IAD-LAS
# r=0
# Round2
# IAD-MCO
# r=0
# Round2
# r=0
# indirect
# IAD-MDW
# r=0
# Round2
# IAD-TPA
# r=0
# Round2
# r=0
# indirect
# IND-BWI
# r=0
# Round2
# r=0
# indirect
# IND-JAX
# r=0
# Round2
# IND-LAS
# r=0
# Round2
# r=0
# indirect
# IND-MCI
# IND-MCO
# r=0
# Round2
# r=0
# indirect
# IND-MDW
# r=0
# Round2
# IND-PHX
# r=0
# Round2
# r=0
# indirect
# IND-TPA
# r=0
# Round2
# ISP-BWI
# r=0
# Round2
# ISP-FLL
# r=0
# Round2
# r=0
# indirect
# ISP-LAS
# ISP-MCO
# r=0
# Round2
# r=0
# indirect
# ISP-MDW
# r=0
# Round2
# r=0
# indirect
# ISP-PBI
# r=0
# Round2
# r=0
# indirect
# ISP-RSW
# r=0
# Round2
# r=0
# indirect
# ISP-TPA
# r=0
# Round2
# r=0
# indirect
# JAN-BWI
# r=0
# Round2
# r=0
# indirect
# JAN-HOU
# r=0
# Round2
# JAN-MCO
# r=0
# Round2
# r=0
# indirect
# JAN-MDW
# r=0
# Round2
# r=0
# indirect
# JAX-BHM
# r=0
# Round2
# r=0
# indirect
# JAX-BNA
# JAX-BWI
# r=0
# Round2
# JAX-FLL
# r=0
# Round2
# r=0
# indirect
# JAX-HOU
# r=0
# Round2
# r=0
# indirect
# JAX-IND
# r=0
# Round2
# r=0
# indirect
# JAX-ORF
# JAX-PHL
# r=0
# Round2
# JAX-TPA
# LAS-ABQ
# r=0
# Round2
# r=0
# indirect
# LAS-ALB
# r=0
# Round2
# r=0
# indirect
# LAS-AMA
# LAS-AUS
# r=0
# Round2
# r=0
# indirect
# LAS-BDL
# r=0
# Round2
# r=0
# indirect
# LAS-BHM
# LAS-BNA
# r=0
# Round2
# r=0
# indirect
# LAS-BOI
# r=0
# Round2
# r=0
# indirect
# LAS-BUF
# r=0
# Round2
# LAS-BUR
# r=0
# Round2
# LAS-BWI
# LAS-CLE
# LAS-CMH
# LAS-DEN
# r=0
# Round2
# r=0
# indirect
# LAS-ELP
# r=0
# Round2
# r=0
# indirect
# LAS-GEG
# r=0
# Round2
# r=0
# indirect
# LAS-HOU
# r=0
# Round2
# LAS-IAD
# r=0
# Round2
# LAS-IND
# r=0
# Round2
# r=0
# indirect
# LAS-ISP
# LAS-LAX
# r=0
# Round2
# r=0
# indirect
# LAS-LBB
# r=0
# Round2
# r=0
# indirect
# LAS-LIT
# r=0
# Round2
# r=0
# indirect
# LAS-MAF
# r=0
# Round2
# LAS-MCI
# LAS-MCO
# r=0
# Round2
# r=0
# indirect
# LAS-MDW
# r=0
# Round2
# r=0
# indirect
# LAS-MHT
# LAS-MSY
# LAS-OAK
# r=0
# Round2
# r=0
# indirect
# LAS-OKC
# LAS-OMA
# LAS-ONT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/LAS/ORF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LAS-ORF
# LAS-PDX
# LAS-PHL
# r=0
# Round2
# LAS-PHX
# r=0
# Round2
# LAS-PIT
# r=0
# Round2
# r=0
# indirect
# LAS-PVD
# r=0
# Round2
# r=0
# indirect
# LAS-RDU
# r=0
# Round2
# LAS-RNO
# LAS-SAN
# LAS-SAT
# r=0
# Round2
# r=0
# indirect
# LAS-SDF
# LAS-SEA
# LAS-SJC
# r=0
# Round2
# LAS-SLC
# LAS-SMF
# r=0
# Round2
# LAS-SNA
# r=0
# Round2
# LAS-STL
# LAS-TPA
# r=0
# Round2
# LAS-TUL
# r=0
# Round2
# LAS-TUS
# r=0
# Round2
# LAX-ABQ
# r=0
# Round2
# LAX-AUS
# r=0
# Round2
# LAX-BNA
# LAX-BWI
# r=0
# Round2
# LAX-ELP
# r=0
# Round2
# r=0
# indirect
# LAX-HOU
# LAX-LAS
# LAX-MCI
# r=0
# Round2
# r=0
# indirect
# LAX-MDW
# LAX-OAK
# LAX-PHL
# r=0
# Round2
# LAX-PHX
# r=0
# Round2
# LAX-RNO
# r=0
# Round2
# LAX-SAT
# LAX-SJC
# LAX-SLC
# LAX-SMF
# r=0
# Round2
# LAX-STL
# LAX-TUS
# r=0
# Round2
# r=0
# indirect
# LBB-ABQ
# r=0
# Round2
# r=0
# indirect
# LBB-AUS
# r=0
# Round2
# r=0
# indirect
# LBB-DAL
# r=0
# Round2
# r=0
# indirect
# Not working for https://www.skyscanner.com/transport/flights/LBB/ELP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LBB-ELP
# r=0
# Round2
# r=0
# indirect
# LBB-LAS
# r=0
# Round2
# r=0
# indirect
# LIT-BWI
# r=0
# Round2
# r=0
# indirect
# LIT-DAL
# r=0
# Round2
# r=0
# indirect
# LIT-HOU
# r=0
# Round2
# r=0
# indirect
# LIT-LAS
# r=0
# Round2
# r=0
# indirect
# LIT-MDW
# r=0
# Round2
# r=0
# indirect
# LIT-PHX
# r=0
# Round2
# LIT-STL
# r=0
# Round2
# r=0
# indirect
# MAF-ABQ
# r=0
# Round2
# r=0
# indirect
# MAF-AUS
# r=0
# Round2
# r=0
# indirect
# MAF-DAL
# r=0
# Round2
# r=0
# indirect
# MAF-ELP
# r=0
# Round2
# r=0
# indirect
# MAF-HOU
# r=0
# Round2
# r=0
# indirect
# MAF-LAS
# r=0
# Round2
# r=0
# indirect
# MCI-ABQ
# r=0
# Round2
# r=0
# indirect
# MCI-BNA
# r=0
# Round2
# r=0
# indirect
# MCI-BWI
# r=0
# Round2
# r=0
# indirect
# MCI-DAL
# r=0
# Round2
# MCI-DEN
# r=0
# Round2
# r=0
# indirect
# MCI-IND
# MCI-LAS
# MCI-LAX
# MCI-MCO
# r=0
# Round2
# r=0
# indirect
# MCI-MDW
# r=0
# Round2
# r=0
# indirect
# MCI-OAK
# r=0
# Round2
# r=0
# indirect
# MCI-OKC
# r=0
# Round2
# MCI-PDX
# r=0
# Round2
# MCI-PHX
# r=0
# Round2
# MCI-SAN
# r=0
# Round2
# MCI-SEA
# r=0
# Round2
# r=0
# indirect
# MCI-SMF
# r=0
# Round2
# MCI-STL
# r=0
# Round2
# r=0
# indirect
# MCI-TPA
# r=0
# Round2
# r=0
# indirect
# MCI-TUL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MCO/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCO-ABQ
# r=0
# Round2
# r=0
# indirect
# MCO-ALB
# MCO-AUS
# MCO-BDL
# r=0
# Round2
# r=0
# indirect
# MCO-BHM
# MCO-BNA
# r=0
# Round2
# MCO-BUF
# MCO-BWI
# MCO-CMH
# MCO-DEN
# MCO-DTW
# r=0
# Round2
# MCO-FLL
# r=0
# Round2
# r=0
# indirect
# MCO-HOU
# r=0
# Round2
# MCO-IAD
# MCO-IND
# r=0
# Round2
# MCO-ISP
# r=0
# Round2
# MCO-JAN
# MCO-LAS
# r=0
# Round2
# MCO-MCI
# r=0
# Round2
# r=0
# indirect
# MCO-MDW
# r=0
# Round2
# r=0
# indirect
# MCO-MHT
# MCO-MSY
# r=0
# Round2
# r=0
# indirect
# MCO-ORF
# MCO-PHL
# r=0
# Round2
# MCO-PHX
# MCO-PIT
# MCO-PVD
# MCO-RDU
# r=0
# Round2
# MCO-RSW
# r=0
# Round2
# r=0
# indirect
# MCO-SAT
# r=0
# Round2
# r=0
# indirect
# MCO-SDF
# MCO-STL
# r=0
# Round2
# r=0
# indirect
# MDW-ABQ
# r=0
# Round2
# r=0
# indirect
# MDW-ALB
# r=0
# Round2
# r=0
# indirect
# MDW-AUS
# r=0
# Round2
# r=0
# indirect
# MDW-BDL
# r=0
# Round2
# r=0
# indirect
# MDW-BHM
# r=0
# Round2
# r=0
# indirect
# MDW-BNA
# r=0
# Round2
# r=0
# indirect
# MDW-BUF
# r=0
# Round2
# r=0
# indirect
# MDW-BWI
# r=0
# Round2
# MDW-CLE
# r=0
# Round2
# r=0
# indirect
# MDW-CMH
# r=0
# Round2
# r=0
# indirect
# MDW-DEN
# r=0
# Round2
# MDW-DTW
# r=0
# Round2
# r=0
# indirect
# MDW-FLL
# r=0
# Round2
# r=0
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-HOU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/IAD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-IAD
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/IND/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-IND
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/ISP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-ISP
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/JAN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-JAN
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/LAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-LAX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/LIT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-LIT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-MCI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-MCO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/MHT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-MHT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/MSY/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-MSY
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/OAK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-OAK
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/OMA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-OMA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/ORF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-ORF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/PDX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-PDX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-PHL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/PIT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-PIT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/PVD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-PVD
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/RDU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-RDU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/RNO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-RNO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/RSW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-RSW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SAN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SAN
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SAT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SAT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SDF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SDF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SEA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SEA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SJC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SJC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SLC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SLC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SMF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SMF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/SNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-SNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/STL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-STL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-TPA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MDW/TUS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-TUS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MHT/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MHT-BWI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MHT/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MHT-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MHT/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MHT-MCO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MHT/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MHT-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MHT/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MHT-PHL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MHT/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MHT-TPA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-BNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-BWI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/DAL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-DAL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/FLL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-FLL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-HOU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-MCO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/MSY/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MSY-TPA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-ABQ
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-BNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/BOI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-BOI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/BUR/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-BUR
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-BWI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/GEG/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-GEG
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-HOU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/LAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-LAX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-MCI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/ONT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-ONT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/PDX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-PDX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-PHL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/RNO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-RNO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/SAN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SAN
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/SEA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SEA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/SLC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SLC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OAK/SNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OKC/DAL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-DAL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OKC/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-HOU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OKC/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OKC/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-MCI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OKC/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OKC/STL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-STL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OMA/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OMA/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OMA/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/OMA/STL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-STL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ONT/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-BNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ONT/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ONT/OAK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-OAK
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ONT/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ONT/SJC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-SJC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ONT/SMF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-SMF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ORF/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-BWI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ORF/JAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-JAX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ORF/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ORF/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-MCO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/ORF/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PBI/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-BWI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PBI/ISP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-ISP
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PBI/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-PHL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PBI/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-TPA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-ABQ
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/BOI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-BOI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/GEG/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-GEG
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-MCI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/OAK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-OAK
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/RNO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-RNO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/SJC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-SJC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/SLC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-SLC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PDX/SMF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-SMF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/BDL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-BDL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-BNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/CMH/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-CMH
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/FLL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-FLL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-HOU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/JAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-JAX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/LAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-LAX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-MCO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/MHT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-MHT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/OAK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-OAK
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/PBI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-PBI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHL/PIT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHL-PIT
# PHL-PVD
# r=0
# Round2
# PHL-RDU
# r=0
# Round2
# PHL-RSW
# PHL-TPA
# r=0
# Round2
# PHX-ABQ
# r=0
# Round2
# PHX-AUS
# r=0
# Round2
# r=0
# indirect
# PHX-BHM
# r=0
# Round2
# r=0
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-BNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/BOI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-BOI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/BUF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-BUF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/BUR/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-BUR
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-BWI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/CLE/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-CLE
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/CMH/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-CMH
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/DEN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-DEN
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/DTW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-DTW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/ELP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-ELP
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-HOU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/IND/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-IND
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/LAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-LAX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/LIT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-LIT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-MCI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-MCO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/MSY/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-MSY
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/OAK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-OAK
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/OKC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-OKC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/OMA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-OMA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/ONT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-ONT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/PDX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-PDX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-PHL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/PIT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-PIT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/PVD/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-PVD
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/RDU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-RDU
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/RNO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-RNO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SAN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SAN
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SAT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SAT
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SDF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SDF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SEA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SEA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SJC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SJC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SLC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SLC
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SMF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SMF
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/SNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-SNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/STL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-STL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-TPA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PHX/TUL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PHX-TUL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PIT/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIT-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PIT/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIT-MCO
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PIT/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIT-MDW
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PIT/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIT-PHL
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PIT/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIT-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PIT/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PIT-TPA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PVD/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-BNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PVD/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-BWI
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PVD/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-LAS
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PVD/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-MCO
# r=0
# Round2
# indirect
# PVD-MDW
# Round2
# PVD-PHL
# Round2
# r=0
# indirect
# PVD-PHX
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/PVD/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PVD-TPA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/RDU/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RDU-BNA
# Round2
# indirect
# Not working for https://www.skyscanner.com/transport/flights/RDU/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RDU-BWI
# Round2
# RDU-LAS
# Round2
# RDU-MCO
# Round2
# r=0
# indirect
# RDU-MDW
# RDU-PHL
# Round2
# RDU-PHX
# RDU-TPA
# RNO-BOI
# Round2
# indirect
# RNO-LAS
# RNO-LAX
# r=0
# Round2
# r=0
# indirect
# RNO-MDW
# Round2
# RNO-OAK
# RNO-PDX
# Round2
# RNO-PHX
# RNO-SEA
# RNO-SJC
# r=0
# Round2
# RNO-SLC
# r=0
# Round2
# r=0
# indirect
# Not working for https://www.skyscanner.com/transport/flights/RSW/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# RSW-BWI
# r=0
# Round2
# r=0
# indirect
# RSW-ISP
# RSW-MCO
# Round2
# r=0
# indirect
# RSW-MDW
# Round2
# RSW-PHL
# Round2
# SAN-ABQ
# SAN-AUS
# Round2
# r=0
# indirect
# SAN-BNA
# SAN-BWI
# SAN-ELP
# Round2
# SAN-LAS
# Round2
# SAN-MCI
# Round2
# r=0
# indirect
# SAN-MDW
# r=0
# Round2
# indirect
# SAN-OAK
# Round2
# SAN-PHX
# r=0
# Round2
# r=0
# indirect
# SAN-SAT
# Round2
# indirect
# SAN-SJC
# SAN-SMF
# r=0
# Round2
# r=0
# indirect
# SAN-TUS
# Round2
# r=0
# indirect
# SAT-BNA
# Round2
# r=0
# indirect
# SAT-BWI
# r=0
# Round2
# r=0
# indirect
# SAT-DAL
# r=0
# Round2
# r=0
# indirect
# SAT-ELP
# Round2
# SAT-HOU
# Round2
# r=0
# indirect
# SAT-HRL
# SAT-LAS
# Round2
# indirect
# SAT-LAX
# Round2
# r=0
# indirect
# SAT-MCO
# r=0
# Round2
# r=0
# indirect
# SAT-MDW
# SAT-PHX
# r=0
# Round2
# r=0
# indirect
# SAT-SAN
# Round2
# r=0
# indirect
# SAT-TPA
# Round2
# r=0
# indirect
# SDF-BHM
# r=0
# Round2
# r=0
# indirect
# SDF-BWI
# Round2
# SDF-LAS
# Round2
# r=0
# indirect
# SDF-MCO
# r=0
# Round2
# r=0
# indirect
# SDF-MDW
# Round2
# r=0
# indirect
# SDF-PHX
# SDF-STL
# r=0
# Round2
# indirect
# SDF-TPA
# Round2
# indirect
# SEA-ABQ
# r=0
# Round2
# SEA-BNA
# Round2
# SEA-BOI
# r=0
# Round2
# SEA-GEG
# Round2
# SEA-LAS
# Round2
# SEA-MCI
# r=0
# Round2
# r=0
# indirect
# SEA-MDW
# SEA-OAK
# SEA-PHX
# Round2
# SEA-RNO
# SEA-SJC
# Round2
# SEA-SLC
# Round2
# SEA-SMF
# SJC-BUR
# SJC-LAS
# SJC-LAX
# Round2
# r=0
# indirect
# SJC-MDW
# Round2
# r=0
# indirect
# SJC-ONT
# Round2
# SJC-PDX
# SJC-PHX
# SJC-RNO
# r=0
# Round2
# SJC-SAN
# r=0
# Round2
# SJC-SEA
# Round2
# SJC-SNA
# r=0
# Round2

# %%
prices1

# %%
if prices['origin'][0]=='SMF':
    print('YES')

# %%
def skyscannerscraper(dep,arr,date, direct='true'):
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # direct: indicates whether direct flight is preferred
    driver = webdriver.Firefox(executable_path='/Users/Christian/Dropbox/Universitet/TSODAS/test/geckodriver')
    driver.implicitly_wait(6)
    wait = WebDriverWait(driver, 12)
    #urlbase = 'https://www.skyscanner.dk/transport/fly/'
    #urlpas = '/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    #urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    urlbase = 'https://www.skyscanner.com/transport/flights/'
    urlpas='/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    data = []

    for depa,arri in zip(dep,arr):
        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend


        driver.get(url)
            
        try:
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))
            
            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
            duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]


            data.append({
                "price": price[1],
                "duration": duration[1],
                "origin": str(depa),
                "destination": str(arri),
                "day":0
                    })
        except (TimeoutException,StaleElementReferenceException,BaseException):
            try:
                WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]
                
                data.append({
                "price": price[1],
                "duration": duration[1],
                "origin": str(depa),
                "destination": str(arri),
                "day":0
                    })    
            except (TimeoutException,StaleElementReferenceException,BaseException):
                try:
                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "price")))
                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "LegInfo__duration-2VgVw")))

                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, "price")]
                    duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "LegInfo__duration-2VgVw")]


                    data.append({
                    "price": price[0],
                    "duration": duration[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "day":0
                        })  
                except (TimeoutException,StaleElementReferenceException,BaseException) :
                    try:
                        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date+1) + urlpas + direct + urlend


                        driver.get(url)
                            

                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                        price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                        duration = [dur.text for dur in driver.find_elements(By.XPATH, "/html/body/div[3]/div[2]/div/div[4]/section[3]/div/div[1]/div[3]/div/table/tbody/tr/td[2]/button/span[3]")]


                        data.append({
                                "price": price[1],
                                "duration": duration[1],
                                "origin": str(depa),
                                "destination": str(arri),
                                "day":1
                                    })
                    except (TimeoutException,StaleElementReferenceException,BaseException):
                        try:
                            WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                            duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]

                            data.append({
                            "price": price[1],
                            "duration": duration[1],
                            "origin": str(depa),
                            "destination": str(arri),
                            "day":1
                                    })    
                        except (TimeoutException,StaleElementReferenceException,BaseException):  
                            try:
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "price")))
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "LegInfo__duration-2VgVw")))

                                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "price")]
                                duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "LegInfo__duration-2VgVw")]


                                data.append({
                                "price": price[0],
                                "duration": duration[0],
                                "origin": str(depa),
                                "destination": str(arri),
                                "day":1
                                     }) 
                            except (TimeoutException,StaleElementReferenceException,BaseException):
                                try:
                                    url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date+2) + urlpas + direct + urlend


                                    driver.get(url)
                                        

                                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                                    duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]


                                    data.append({
                                            "price": price[1],
                                            "duration": duration[1],
                                            "origin": str(depa),
                                            "destination": str(arri),
                                            "day":2
                                                })
                                except (TimeoutException,StaleElementReferenceException,BaseException):
                                    try:
                                        WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                                        price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                                        duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]

                                        data.append({
                                        "price": price[1],
                                        "duration": duration[1],
                                        "origin": str(depa),
                                        "destination": str(arri),
                                           "day":2
                                                })    
                                    except (TimeoutException,StaleElementReferenceException,BaseException):  
                                        try:
                                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "price")))
                                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "LegInfo__duration-2VgVw")))

                                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "price")]
                                            duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "LegInfo__duration-2VgVw")]


                                            data.append({
                                            "price": price[0],
                                            "duration": duration[0],
                                            "origin": str(depa),
                                            "destination": str(arri),
                                            "day":2
                                                 }) 
                                        except (TimeoutException,StaleElementReferenceException,BaseException): 
                                            try:
                                                url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend


                                                driver.get(url)
                                                wait.until(EC.visibility_of_element_located((By.XPATH, "/html/body/div[2]/div[2]/div/div[4]/section[3]/div/div[2]/div[2]/div[2]/dl[1]/dd/ol/li[3]/label/span[2]")))
                                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME,'CTASection__unpriced-label-29y5u')))
                                                price = [price.text for price in driver.find_elements(By.XPATH, "/html/body/div[2]/div[2]/div/div[4]/section[3]/div/div[2]/div[2]/div[2]/dl[1]/dd/ol/li[3]/label/span[2]")]
                                                findes_d = [direk.text for direk in driver.find_elements(By.XPATH,"""//*[@id="16388-1905271000--31829-0-15040-1905271125"]/div/div[1]/div/div/div[2]/div[2]/div[2]/div/span[1]""")]
                                                data.append({
                                                "price": price,
                                                "duration": "-",
                                                "origin": str(depa),
                                                "destination": str(arri),
                                                "day":0,
                                                "findes_direkte":findes_d[0],
                                                "indirect":1
                                                     }) 
                                                
                                            except (TimeoutException,StaleElementReferenceException,BaseException):
                                                print("No working for "+str(url))
                                                data.append({
                                                "price": "-",
                                                "duration": "-",
                                                "origin": str(depa),
                                                "destination": str(arri),
                                                "day":"-"
                                                     }) 
        print(str(depa)+"-"+str(arri))
    driver.close()
                
    price_data = pd.DataFrame(data)                                            
    return price_data

# %%
start=time.time()
prices=skyscannerscraper(data1['Origin'],data1['Dest'],190527, direct='true')
stop =time.time()
# Out:
# SMF-ONT

# %%
prices

# %%
def skyscannerscraper(dep,arr,date, direct='true'):
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # direct: indicates whether direct flight is preferred
    driver = webdriver.Firefox(executable_path='/Users/Christian/Dropbox/Universitet/TSODAS/test/geckodriver')
    driver.implicitly_wait(6)
    wait = WebDriverWait(driver, 12)
    #urlbase = 'https://www.skyscanner.dk/transport/fly/'
    #urlpas = '/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    #urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    urlbase = 'https://www.skyscanner.com/transport/flights/'
    urlpas='/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    data = []

    for depa,arri in zip(dep,arr):
        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend


        driver.get(url)
            
        try:
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))
            
            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
            duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]


            data.append({
                "price": price[1],
                "duration": duration[1],
                "origin": str(depa),
                "destination": str(arri),
                "day":0
                    })
        except (TimeoutException,StaleElementReferenceException,BaseException):
            try:
                wait.until(EC.visibility_of_element_located((By.XPATH, "/html/body/div[2]/div[2]/div/div[4]/section[3]/div/div[2]/div[2]/div[2]/dl[1]/dd/ol/li[3]/label/span[2]")))
                wait.until(EC.visibility_of_element_located((By.CLASS_NAME,'CTASection__unpriced-label-29y5u')))
                price = [price.text for price in driver.find_elements(By.XPATH, "/html/body/div[2]/div[2]/div/div[4]/section[3]/div/div[2]/div[2]/div[2]/dl[1]/dd/ol/li[3]/label/span[2]")]
                findes_d = [direk.text for direk in driver.find_elements(By.CLASS_NAME,"LegInfo__stops-label-1sfT2 LegInfo__stops-green-BoNBD")]
                data.append({
                        "price": price,
                        "duration": "-",
                        "origin": str(depa),
                        "destination": str(arri),
                        "day":0,
                        "findes_direkte":findes_d[0],
                        "indirect":1
                          }) 
                
            except (TimeoutException,StaleElementReferenceException,BaseException):
                    try:
                        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date+1) + urlpas + direct + urlend


                        driver.get(url)
                            

                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                        price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                        duration = [dur.text for dur in driver.find_elements(By.XPATH, "/html/body/div[3]/div[2]/div/div[4]/section[3]/div/div[1]/div[3]/div/table/tbody/tr/td[2]/button/span[3]")]


                        data.append({
                                "price": price[1],
                                "duration": duration[1],
                                "origin": str(depa),
                                "destination": str(arri),
                                "day":1
                                    })
                    except (TimeoutException,StaleElementReferenceException,BaseException):
                        try:
                            WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                            duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]

                            data.append({
                            "price": price[1],
                            "duration": duration[1],
                            "origin": str(depa),
                            "destination": str(arri),
                            "day":1
                                    })    
                        except (TimeoutException,StaleElementReferenceException,BaseException):  
                            try:
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "price")))
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "LegInfo__duration-2VgVw")))

                                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "price")]
                                duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "LegInfo__duration-2VgVw")]


                                data.append({
                                "price": price[0],
                                "duration": duration[0],
                                "origin": str(depa),
                                "destination": str(arri),
                                "day":1
                                     }) 
                            except (TimeoutException,StaleElementReferenceException,BaseException):
                                try:
                                    url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date+2) + urlpas + direct + urlend


                                    driver.get(url)
                                        

                                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                                    duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]


                                    data.append({
                                            "price": price[1],
                                            "duration": duration[1],
                                            "origin": str(depa),
                                            "destination": str(arri),
                                            "day":2
                                                })
                                except (TimeoutException,StaleElementReferenceException,BaseException):
                                    try:
                                        WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-price")))
                                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "fqs-duration")))

                                        price = [price.text for price in driver.find_elements(By.CLASS_NAME, "fqs-price")]
                                        duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "fqs-duration")]

                                        data.append({
                                        "price": price[1],
                                        "duration": duration[1],
                                        "origin": str(depa),
                                        "destination": str(arri),
                                           "day":2
                                                })    
                                    except (TimeoutException,StaleElementReferenceException,BaseException):  
                                        try:
                                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "price")))
                                            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "LegInfo__duration-2VgVw")))

                                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "price")]
                                            duration = [dur.text for dur in driver.find_elements(By.CLASS_NAME, "LegInfo__duration-2VgVw")]


                                            data.append({
                                            "price": price[0],
                                            "duration": duration[0],
                                            "origin": str(depa),
                                            "destination": str(arri),
                                            "day":2
                                                 }) 
                                        except (TimeoutException,StaleElementReferenceException,BaseException): 
                                            try:
                                                url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend


                                                driver.get(url)
                                                wait.until(EC.visibility_of_element_located((By.XPATH, "/html/body/div[2]/div[2]/div/div[4]/section[3]/div/div[2]/div[2]/div[2]/dl[1]/dd/ol/li[3]/label/span[2]")))
                                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME,'CTASection__unpriced-label-29y5u')))
                                                price = [price.text for price in driver.find_elements(By.XPATH, "/html/body/div[2]/div[2]/div/div[4]/section[3]/div/div[2]/div[2]/div[2]/dl[1]/dd/ol/li[3]/label/span[2]")]
                                                findes_d = [direk.text for direk in driver.find_elements(By.XPATH,"""//*[@id="16388-1905271000--31829-0-15040-1905271125"]/div/div[1]/div/div/div[2]/div[2]/div[2]/div/span[1]""")]
                                                data.append({
                                                "price": price,
                                                "duration": "-",
                                                "origin": str(depa),
                                                "destination": str(arri),
                                                "day":0,
                                                "findes_direkte":findes_d[0],
                                                "indirect":1
                                                     }) 
                                                
                                            except (TimeoutException,StaleElementReferenceException,BaseException):
                                                print("No working for "+str(url))
                                                data.append({
                                                "price": "-",
                                                "duration": "-",
                                                "origin": str(depa),
                                                "destination": str(arri),
                                                "day":"-"
                                                     }) 
        print(str(depa)+"-"+str(arri))
    driver.close()
                
    price_data = pd.DataFrame(data)                                            
    return price_data

# %%
prices
# Out:
#    day destination                                              label origin  \
# 0    0         ONT  [Direkte, 1 omstigning, 2+ omstigningner, Alas...    SMF
#
#                                                price
# 0  [ , kr. 1.067, kr. 2.178, kr. 1.625, kr. 1.563...

# %%
def momondoscraper(dep,arr,yyyy,mm,dd, direct=0):
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # direct: indicates whether direct flight is preferred
    driver = webdriver.Firefox(executable_path='/Users/Christian/Dropbox/Universitet/TSODAS/test/geckodriver')
    driver.implicitly_wait(12)
    wait = WebDriverWait(driver, 12)
    urlbase='https://www.momondo.com/flight-search/'
    #https://www.momondo.com/flight-search/SMF-PHX/2019-06-06?sort=price_a&fs=stops=0
    #https://www.momondo.com/flight-search/SMF-PHX/2019-06-05?sort=price_a&fs=airlines=-WN;stops=0
    
    urlpas='?sort=duration_a&fs=stops='

    data = []

    for depa,arri in zip(dep,arr):
        url = urlbase + str(depa) + str('-') + str(arri) + str('/')+ str(yyyy)+str('-')+ str(mm)+str('-')+ str(dd) + urlpas + str(direct)


        driver.get(url)
            
        try:
            
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
                                    
            price = [price.text for price in driver.find_elements(By.CLASS_NAME, 'display-price')]
            duration = [duration.text for duration in driver.find_elements(By.CLASS_NAME, 'section-duration')]


            data.append({
                "price": price[0],
                "duration": duration[0],
                "origin": str(depa),
                "destination": str(arri),
                "duration" : duration[0],
                "day":0
                    })
        except (TimeoutException,StaleElementReferenceException,BaseException):
                    try:
                        url = urlbase + str(depa) + str('-') + str(arri) + str('/')+ str(yyyy)+str('-')+ str(mm)+str('-')+ str(dd+1) + urlpas + str(direct)



                        driver.get(url)
                            
                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
                                    
                        price = [price.text for price in driver.find_elements(By.CLASS_NAME, 'display-price')]
                        duration = [duration.text for duration in driver.find_elements(By.CLASS_NAME, 'section-duration')]

                        data.append({
                                "price": price[0],
                                "origin": str(depa),
                                "destination": str(arri),
                                "duration" : duration[0],
                                "day":1
                                    })
                    except (TimeoutException,StaleElementReferenceException,BaseException): 
                                try:
                                    url = urlbase + str(depa) + str('-') + str(arri) + str('/')+ str(yyyy)+str('-')+ str(mm)+str('-')+ str(dd+2) + urlpas + str(direct)



                                    driver.get(url)
                                        
                                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
                                    wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
                                    
                                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, 'display-price')]
                                    duration = [duration.text for duration in driver.find_elements(By.CLASS_NAME, 'section-duration')]


            

                                    data.append({
                                            "price": price[0],
                                            "origin": str(depa),
                                            "destination": str(arri),
                                            "duration" : duration[0],
                                            "day":2
                                                })
                                except (TimeoutException,StaleElementReferenceException,BaseException):
                                    try:
                                        urlpas='?sort=duration_a&fs=airlines=-WN;stops='
                                        url = urlbase + str(depa) + str('-') + str(arri) + str('/')+ str(yyyy)+str('-')+ str(mm)+str('-')+ str(dd) + urlpas + str(direct)
                                        driver.get(url)
                                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
                                        wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
                                    
                                        price = [price.text for price in driver.find_elements(By.CLASS_NAME, 'display-price')]
                                        duration = [duration.text for duration in driver.find_elements(By.CLASS_NAME, 'section-duration')]
                                        data.append({
                                            "price": price[0],
                                            "origin": str(depa),
                                            "destination": str(arri),
                                            "day":0,
                                            "duration" : duration[0],
                                            "direct":0
                                                })
                                    except (TimeoutException,StaleElementReferenceException,BaseException):
                                                print("No working for"+str(url))
                                                data.append({
                                                "price": "-",
                                                "origin": str(depa),
                                                "destination": str(arri),
                                                "duration" : duration[0],
                                                "day":"-"
                                                     }) 
        print(str(depa)+"-"+str(arri))
    driver.close()
                
    price_data = pd.DataFrame(data)                                            
    return price_data

# %%
price=momondoscraper(data1['Origin'],data1['Dest'],2019,10,28)
# Out:
# No working forhttps://www.momondo.com/flight-search/SMF-ONT/2019-10-28?sort=duration_a&fs=airlines=-WN;stops=0
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-81-8232a30540a7> in momondoscraper(dep, arr, yyyy, mm, dd, direct)
#      26             wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
# ---> 27             wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
#      28
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#
# TimeoutException: Message:
#
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-81-8232a30540a7> in momondoscraper(dep, arr, yyyy, mm, dd, direct)
#      49                         wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
# ---> 50                         wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
#      51
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#
# TimeoutException: Message:
#
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-81-8232a30540a7> in momondoscraper(dep, arr, yyyy, mm, dd, direct)
#      70                                     wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
# ---> 71                                     wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
#      72
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#
# TimeoutException: Message:
#
#
# During handling of the above exception, another exception occurred:
#
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-81-8232a30540a7> in momondoscraper(dep, arr, yyyy, mm, dd, direct)
#      91                                         wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'display-price')))
# ---> 92                                         wait.until(EC.visibility_of_element_located((By.CLASS_NAME, 'section-duration')))
#      93
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#
# TimeoutException: Message:
#
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-82-809ab1492d88> in <module>
# ----> 1 price=momondoscraper(data1['Origin'],data1['Dest'],2019,10,28)
#
# <ipython-input-81-8232a30540a7> in momondoscraper(dep, arr, yyyy, mm, dd, direct)
#     108                                                 "origin": str(depa),
#     109                                                 "destination": str(arri),
# --> 110                                                 "duration" : duration[0],
#     111                                                 "day":"-"
#     112                                                      })
#
# UnboundLocalError: local variable 'duration' referenced before assignment

# %%
from random import randint
import random
def kandidattest():
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # direct: indicates whether direct flight is preferred
    driver = webdriver.Firefox(executable_path='/Users/Christian/Dropbox/Universitet/TSODAS/test/geckodriver')
    driver.implicitly_wait(8)
    wait = WebDriverWait(driver, 10)
    data = []
    url='https://www.dr.dk/nyheder/politik/kandidattest'
    driver.get(url)
    for val in range[1:31]:
        
        x=randint(1,4)
        xpath='/html/body/div[3]/div/div[3]/div/div[1]/div[2]/section/div/article['+str(val)+']/div[3]/div/div[2]/button['+str(x)+']'
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,xpath)))

# %%
from random import randint

driver = webdriver.Firefox(executable_path='/Users/Christian/Dropbox/Universitet/TSODAS/test/geckodriver')
driver.implicitly_wait(8)
wait = WebDriverWait(driver, 10)
data = []
url='https://www.dr.dk/nyheder/politik/kandidattest'
driver.get(url)
WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="CybotCookiebotDialogBodyButtonAccept"]"""))).click()
x=randint(1,4)
print(x)
#try:
time.sleep(5)
if x==1:
                                                                                #/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[1]
                                                                                #/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[2]/div[3]/div/div[2]/button[1]
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[1]'))).click()
elif x==2:
                                                                               # /html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[2]
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[2]'))).click()
elif x==3:
                                                                               # /html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[3]
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[3]'))).click()
else:
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[4]'))).click()
#except (TimeoutException,StaleElementReferenceException,BaseException):
#        
#    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME,'CybotCookiebotDialogBodyButton'))).click()
#    if x==1:
#        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[3]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[1]'))).click()
#    elif x==2:
#        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[3]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[2]'))).click()
#    elif x==3:
#        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[3]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[3]'))).click()
#    else:
#        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[3]/div/div[3]/div/div[1]/div[2]/section/div/article[1]/div[3]/div/div[2]/button[4]'))).click()
# Out:
# 1

# %%
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.common.action_chains import ActionChains
def kandidattest(kommune,antal):
    kom=kommune
    driver = webdriver.Firefox(executable_path='/Users/Christian/Dropbox/Universitet/TSODAS/test/geckodriver')
    driver.implicitly_wait(8)
    wait = WebDriverWait(driver, 10)
    data = []
    url='https://www.dr.dk/nyheder/politik/kandidattest'
    for valu in range(0,antal):  
        driver.get(url)
        time.sleep(2)
        try:
            print(valu)
            target = driver.find_element_by_xpath("""//*[@id="skip-party-pre-selection"]""")
            actions = ActionChains(driver)
            actions.move_to_element(target)
            actions.perform()
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="CybotCookiebotDialogBodyButtonAccept"]"""))).click()
            time.sleep(4)
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="CybotCookiebotDialogBodyButtonAccept"]"""))).click()

            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="skip-party-pre-selection"]"""))).click()
            for val in range(1,31):
                random.seed(9001+val)
                x=randint(1,4)
                #wait.until(EC.invisibility_of_element_located((By.XPATH,"/html/body/div[4]/div/div[3]/div/div[2]/div/div")))
                xpath='/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article['+str(val)+']/div[3]/div/div[2]/button['+str(x)+']'
                WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,xpath))).click()
                time.sleep(0.5)
            komm=driver.find_element_by_xpath("""//*[@id="municipality"]""")
            komm.send_keys(kom)
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME,'dr-election-questions__results-button'))).click()
            parti=driver.find_element_by_xpath("/html/body/div[4]/div/div[3]/div/div[1]/div[2]/div/div/div[1]/div/div[1]/div[1]/div/div[1]/a/div/div/div[2]").text
            data.append({
                'parti':parti
            })
            #driver.close()
            time.sleep(2)
        except (TimeoutException,StaleElementReferenceException,BaseException,ElementClickInterceptedException):
            try:
                target = driver.find_element_by_xpath("""//*[@id="skip-party-pre-selection"]""")
                actions = ActionChains(driver)
                actions.move_to_element(target)
                actions.perform()
                WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="skip-party-pre-selection"]"""))).click()
                for val in range(1,31):
                    random.seed(9001+val)
                    x=randint(1,4)
                    #wait.until(EC.invisibility_of_element_located((By.XPATH,"/html/body/div[4]/div/div[3]/div/div[2]/div/div")))
                    xpath='/html/body/div[4]/div/div[3]/div/div[1]/div[2]/section/div/article['+str(val)+']/div[3]/div/div[2]/button['+str(x)+']'
                    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,xpath))).click()
                    time.sleep(0.5)
                komm=driver.find_element_by_xpath("""//*[@id="municipality"]""")
                komm.send_keys(kom)
                WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME,'dr-election-questions__results-button'))).click()
                parti=driver.find_element_by_xpath("/html/body/div[4]/div/div[3]/div/div[1]/div[2]/div/div/div[1]/div/div[1]/div[1]/div/div[1]/a/div/div/div[2]").text
                data.append({
                    'parti':parti
                })
                time.sleep(2)
            except (TimeoutException,StaleElementReferenceException,BaseException,ElementClickInterceptedException):
                try:
                    target = driver.find_element_by_xpath("""//*[@id="skip-party-pre-selection"]""")
                    actions = ActionChains(driver)
                    actions.move_to_element(target)
                    actions.perform()
                    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="skip-party-pre-selection"]"""))).click()
                    for val in range(1,31):
                        random.seed(9001+val)
                        x=randint(1,4)
                        #wait.until(EC.invisibility_of_element_located((By.XPATH,"/html/body/div[4]/div/div[3]/div/div[2]/div/div")))
                        xpath='/html/body/div[3]/div/div[3]/div/div[1]/div[2]/section/div/article['+str(val)+']/div[3]/div/div[2]/button['+str(x)+']'
                        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,xpath))).click()
                        time.sleep(0.5)

                    komm=driver.find_element_by_xpath("""//*[@id="municipality"]""")
                    komm.send_keys(kom)
                    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME,'dr-election-questions__results-button'))).click()
                    parti=driver.find_element_by_xpath("/html/body/div[4]/div/div[3]/div/div[1]/div[2]/div/div/div[1]/div/div[1]/div[1]/div/div[1]/a/div/div/div[2]").text
                    data.append({
                        'parti':parti
                    })
                    time.sleep(2)
                except (TimeoutException,StaleElementReferenceException,BaseException,ElementClickInterceptedException):
                    driver.get(url)
                    time.sleep(2)
                    target = driver.find_element_by_xpath("""//*[@id="skip-party-pre-selection"]""")
                    actions = ActionChains(driver)
                    actions.move_to_element(target)
                    actions.perform()
                    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="skip-party-pre-selection"]"""))).click()
                    for val in range(1,31):
                        random.seed(9001+val)
                        x=randint(1,4)
                        #wait.until(EC.invisibility_of_element_located((By.XPATH,"/html/body/div[4]/div/div[3]/div/div[2]/div/div")))
                        xpath='/html/body/div[3]/div/div[3]/div/div[1]/div[2]/section/div/article['+str(val)+']/div[3]/div/div[2]/button['+str(x)+']'
                        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,xpath))).click()
                        time.sleep(0.5)
                        
                    komm=driver.find_element_by_xpath("""//*[@id="municipality"]""")
                    komm.send_keys(kom)
                    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME,'dr-election-questions__results-button'))).click()
                    parti=driver.find_element_by_xpath("/html/body/div[4]/div/div[3]/div/div[1]/div[2]/div/div/div[1]/div/div[1]/div[1]/div/div[1]/a/div/div/div[2]").text
                    data.append({
                        'parti':parti
                    })
                    time.sleep(2)


    parti_data = pd.DataFrame(data) 
    driver.close() 
    return parti_data

# %%
t=kandidattest('københavn',2)
# Out:
# 0
# ---------------------------------------------------------------------------
# MoveTargetOutOfBoundsException            Traceback (most recent call last)
# <ipython-input-511-12a928758bd8> in kandidattest(kommune, antal)
#      17             actions.move_to_element(target)
# ---> 18             actions.perform()
#      19             WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="CybotCookiebotDialogBodyButtonAccept"]"""))).click()
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/action_chains.py in perform(self)
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/actions/action_builder.py in perform(self)
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# MoveTargetOutOfBoundsException: Message: (640, 797) is out of bounds of viewport width (1280) and height (703)
#
#
# During handling of the above exception, another exception occurred:
#
# MoveTargetOutOfBoundsException            Traceback (most recent call last)
# <ipython-input-511-12a928758bd8> in kandidattest(kommune, antal)
#      44                 actions.move_to_element(target)
# ---> 45                 actions.perform()
#      46                 WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="skip-party-pre-selection"]"""))).click()
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/action_chains.py in perform(self)
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/actions/action_builder.py in perform(self)
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# MoveTargetOutOfBoundsException: Message: (640, 797) is out of bounds of viewport width (1280) and height (703)
#
#
# During handling of the above exception, another exception occurred:
#
# MoveTargetOutOfBoundsException            Traceback (most recent call last)
# <ipython-input-511-12a928758bd8> in kandidattest(kommune, antal)
#      66                     actions.move_to_element(target)
# ---> 67                     actions.perform()
#      68                     WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="skip-party-pre-selection"]"""))).click()
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/action_chains.py in perform(self)
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/actions/action_builder.py in perform(self)
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# MoveTargetOutOfBoundsException: Message: (640, 797) is out of bounds of viewport width (1280) and height (703)
#
#
# During handling of the above exception, another exception occurred:
#
# MoveTargetOutOfBoundsException            Traceback (most recent call last)
# <ipython-input-512-a24c8425a5a8> in <module>
# ----> 1 t=kandidattest('københavn',2)
#
# <ipython-input-511-12a928758bd8> in kandidattest(kommune, antal)
#      89                     actions = ActionChains(driver)
#      90                     actions.move_to_element(target)
# ---> 91                     actions.perform()
#      92                     WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,"""//*[@id="skip-party-pre-selection"]"""))).click()
#      93                     for val in range(1,31):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/action_chains.py in perform(self)
#      78         """
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#      82             for action in self._actions:
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/actions/action_builder.py in perform(self)
#      74             if encoded['actions']:
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
#      78     def clear_actions(self):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# MoveTargetOutOfBoundsException: Message: (640, 797) is out of bounds of viewport width (1280) and height (703)
