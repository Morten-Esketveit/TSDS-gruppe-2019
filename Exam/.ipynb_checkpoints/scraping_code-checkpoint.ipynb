# %%
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import StaleElementReferenceException
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import re
import os
import time

# %%
data_flights=pd.read_pickle('scrape_data.pkl')
data1=data_flights[0:200] # FÆRDIG
data2=data[200:578]       # FÆRDIG
data7=data[578:1000]  
data3=data[1000:2000]     # CHRISTIAN
data4=data[2000:3000]
data5=data[3000:4000]     # THOR
data6=data[4000:]         # MORTEN

# %%
def skyscannerscraper(dep,arr,date, save, driverpath, direct='true'):
    # Function scraping skyscanner.dk
    # dep: airport code for departure airport
    # arr: airport code for arrival airport
    # date: date of flight, format YYMMDD
    # save: filename
    # driverpath: complete path to driver
    # direct: indicates whether direct flight is preferred
    save2=save+".pkl"
    
    driver = webdriver.Firefox(executable_path=driverpath)
    driver.implicitly_wait(7)
    wait = WebDriverWait(driver, 8)
    urlbase = 'https://www.skyscanner.com/transport/flights/'
    urlpas='/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects='
    urlend = '&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results'
    data = []
    count=0
    for depa,arri in zip(dep,arr):
        count+=1
        url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend

        driver.get(url)
        time.sleep(6) 
        try:
            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
            wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
            r=price[0]
            if r==' ':
                del r
                #print('r=0')
                raise ValueError
            elif r=='Ingen':
                #print('r=0')
                raise ValueError
                del r
            else:
                data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                del r
                del price
            
        except (TimeoutException,StaleElementReferenceException,BaseException):
            try:
                WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))
                #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                r=price[0]
                if r==' ':
                    del r
                    #print('r=0')
                    raise ValueError
                elif r=='Ingen':
                    del r
                    #print('r=0')
                    raise ValueError
                else:
                    data.append({
                    "price": price[0],
                    "origin": str(depa),
                    "destination": str(arri),
                    "label": label[0],
                    "day":0
                        })
                    del r
                    del price
                    


            except (TimeoutException,StaleElementReferenceException,BaseException):
                try:
                    time.sleep(3)
                    #print('Round2')
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                    wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                    #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                    price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                    label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                    r=price[0]
                    if r==' ':
                        del r
                        #print('r=0')
                        raise ValueError
                    elif r=='Ingen':
                        #print('r=0')
                        raise ValueError
                        del r
                    else:
                        data.append({
                            "price": price[0],
                            "origin": str(depa),
                            "destination": str(arri),
                            "label": label[0],
                            "day":0
                                })
                        del r
                        del price

                except (TimeoutException,StaleElementReferenceException,BaseException):
                        try:
                            WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, '.bpk-close-button-65MQ0'))).click()
                            wait.until(EC.presence_of_element_located(By.CLASS_NAME, "filter-sub"))
                            wait.until(EC.presence_of_element_located((By.CLASS_NAME, "label-text")))
                            #wait.until(EC.visibility_of_element_located((By.CLASS_NAME,"day-list-count")))
                            price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                            label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                            r=price[0]
                            if r==' ':
                                del r
                                #print('r=0')
                                raise ValueError
                            elif r=='Ingen':
                                del r
                                #print('r=0')
                                raise ValueError
                            else:
                                data.append({
                                "price": price[0],
                                "origin": str(depa),
                                "destination": str(arri),
                                "label": label[0],
                                "day":0
                                    })
                                del r
                                del price

                        except (TimeoutException,StaleElementReferenceException,BaseException):
                            try:
                                #print('indirect')
                                wait.until(EC.presence_of_element_located((By.CLASS_NAME, "filter-sub")))
                                wait.until(EC.visibility_of_element_located((By.CLASS_NAME, "label-text")))

                                price = [price.text for price in driver.find_elements(By.CLASS_NAME, "filter-sub")]
                                label = [label.text for label in driver.find_elements(By.CLASS_NAME, "label-text")]
                                data.append({
                                        "price": price[1],
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": label[1],
                                        "day":0,
                                        "alternative": price[0]
                                            })
                                del price


                            except (TimeoutException,StaleElementReferenceException,BaseException):

                                print("Not working for "+str(url))


                                data.append({
                                        "price": '-',
                                        "origin": str(depa),
                                        "destination": str(arri),
                                        "label": '-',
                                        "day":0
                                            })
                    
        print(str(depa)+"-"+str(arri))
        
        print(str(count)+" af " +str(len(dep.index)))
        time.sleep(2)
        price_data = pd.DataFrame(data)
        if count%20==0:
            price_data.to_pickle(save2)
        if count%200==0:
            time.sleep(300)
            driver.close()
    driver.close()
    
    
    
    return price_data

# %%
# Indsæt driverpath (skal vise lokal path)

prices2=skyscannerscraper(data7['Origin'],data7['Dest'],190527,save='prices_577_1000', driverpath='/Users/Christian/Dropbox/Universitet/TSODAS/TSDS-gruppe-2019/Exam/geckodriver', direct='true')
# Out:
# BWI-LAX
# 1 af 800
# BWI-LIT
# 2 af 800
# BWI-MCI
# 3 af 800
# BWI-MCO
# 4 af 800
# BWI-MDW
# 5 af 800
# BWI-MHT
# 6 af 800
# BWI-MSY
# 7 af 800
# BWI-OAK
# 8 af 800
# Not working for https://www.skyscanner.com/transport/flights/BWI/ORF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# BWI-ORF
# 9 af 800
# BWI-PBI
# 10 af 800
# BWI-PHX
# 11 af 800
# BWI-PVD
# 12 af 800
# BWI-RDU
# 13 af 800
# BWI-RSW
# 14 af 800
# BWI-SAN
# 15 af 800
# BWI-SAT
# 16 af 800
# BWI-SDF
# 17 af 800
# BWI-SLC
# 18 af 800
# BWI-STL
# 19 af 800
# BWI-TPA
# 20 af 800
# CLE-BNA
# 21 af 800
# Not working for https://www.skyscanner.com/transport/flights/CLE/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# CLE-BWI
# 22 af 800
# CLE-LAS
# 23 af 800
# CLE-MDW
# 24 af 800
# CLE-PHX
# 25 af 800
# CLE-STL
# 26 af 800
# CMH-BNA
# 27 af 800
# CMH-BWI
# 28 af 800
# CMH-LAS
# 29 af 800
# CMH-MCO
# 30 af 800
# CMH-MDW
# 31 af 800
# CMH-PHL
# 32 af 800
# CMH-PHX
# 33 af 800
# CMH-STL
# 34 af 800
# CMH-TPA
# 35 af 800
# CRP-HOU
# 36 af 800
# DAL-ABQ
# 37 af 800
# DAL-AMA
# 38 af 800
# DAL-AUS
# 39 af 800
# DAL-ELP
# 40 af 800
# DAL-HOU
# 41 af 800
# DAL-LBB
# 42 af 800
# Not working for https://www.skyscanner.com/transport/flights/DAL/LIT/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# DAL-LIT
# 43 af 800
# DAL-MAF
# 44 af 800
# DAL-MCI
# 45 af 800
# DAL-MSY
# 46 af 800
# DAL-OKC
# 47 af 800
# DAL-SAT
# 48 af 800
# DAL-STL
# 49 af 800
# DAL-TUL
# 50 af 800
# DEN-BNA
# 51 af 800
# DEN-BWI
# 52 af 800
# DEN-HOU
# 53 af 800
# DEN-LAS
# 54 af 800
# DEN-MCI
# 55 af 800
# DEN-MCO
# 56 af 800
# DEN-MDW
# 57 af 800
# DEN-PHX
# 58 af 800
# DEN-SLC
# 59 af 800
# DTW-BNA
# 60 af 800
# DTW-BWI
# 61 af 800
# DTW-MCO
# 62 af 800
# DTW-MDW
# 63 af 800
# DTW-PHX
# 64 af 800
# DTW-STL
# 65 af 800
# ELP-ABQ
# 66 af 800
# ELP-AUS
# 67 af 800
# ELP-DAL
# 68 af 800
# ELP-HOU
# 69 af 800
# ELP-LAS
# 70 af 800
# ELP-LAX
# 71 af 800
# ELP-LBB
# 72 af 800
# ELP-MAF
# 73 af 800
# ELP-PHX
# 74 af 800
# ELP-SAN
# 75 af 800
# ELP-SAT
# 76 af 800
# FLL-BNA
# 77 af 800
# FLL-BWI
# 78 af 800
# FLL-HOU
# 79 af 800
# FLL-ISP
# 80 af 800
# FLL-JAX
# 81 af 800
# FLL-MCO
# 82 af 800
# FLL-MDW
# 83 af 800
# FLL-MSY
# 84 af 800
# FLL-PHL
# 85 af 800
# FLL-STL
# 86 af 800
# FLL-TPA
# 87 af 800
# GEG-BOI
# 88 af 800
# GEG-LAS
# 89 af 800
# GEG-OAK
# 90 af 800
# GEG-PDX
# 91 af 800
# GEG-SEA
# 92 af 800
# GEG-SLC
# 93 af 800
# HOU-ABQ
# 94 af 800
# HOU-AUS
# 95 af 800
# HOU-BHM
# 96 af 800
# HOU-BNA
# 97 af 800
# Not working for https://www.skyscanner.com/transport/flights/HOU/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# HOU-BWI
# 98 af 800
# HOU-CRP
# 99 af 800
# HOU-DAL
# 100 af 800
# HOU-DEN
# 101 af 800
# HOU-ELP
# 102 af 800
# HOU-FLL
# 103 af 800
# HOU-HRL
# 104 af 800
# HOU-JAN
# 105 af 800
# HOU-JAX
# 106 af 800
# HOU-LAS
# 107 af 800
# HOU-LAX
# 108 af 800
# HOU-LIT
# 109 af 800
# HOU-MAF
# 110 af 800
# HOU-MCO
# 111 af 800
# HOU-MDW
# 112 af 800
# HOU-MSY
# 113 af 800
# HOU-OAK
# 114 af 800
# HOU-OKC
# 115 af 800
# HOU-PHL
# 116 af 800
# HOU-PHX
# 117 af 800
# HOU-SAT
# 118 af 800
# HOU-STL
# 119 af 800
# HOU-TPA
# 120 af 800
# HOU-TUL
# 121 af 800
# HRL-AUS
# 122 af 800
# HRL-HOU
# 123 af 800
# HRL-SAT
# 124 af 800
# IAD-LAS
# 125 af 800
# IAD-MCO
# 126 af 800
# IAD-MDW
# 127 af 800
# IAD-TPA
# 128 af 800
# IND-BWI
# 129 af 800
# IND-JAX
# 130 af 800
# IND-LAS
# 131 af 800
# IND-MCI
# 132 af 800
# IND-MCO
# 133 af 800
# IND-MDW
# 134 af 800
# IND-PHX
# 135 af 800
# IND-TPA
# 136 af 800
# ISP-BWI
# 137 af 800
# ISP-FLL
# 138 af 800
# ISP-LAS
# 139 af 800
# ISP-MCO
# 140 af 800
# ISP-MDW
# 141 af 800
# ISP-PBI
# 142 af 800
# ISP-RSW
# 143 af 800
# ISP-TPA
# 144 af 800
# JAN-BWI
# 145 af 800
# JAN-HOU
# 146 af 800
# JAN-MCO
# 147 af 800
# JAN-MDW
# 148 af 800
# JAX-BHM
# 149 af 800
# JAX-BNA
# 150 af 800
# JAX-BWI
# 151 af 800
# JAX-FLL
# 152 af 800
# JAX-HOU
# 153 af 800
# JAX-IND
# 154 af 800
# JAX-ORF
# 155 af 800
# JAX-PHL
# 156 af 800
# JAX-TPA
# 157 af 800
# LAS-ABQ
# 158 af 800
# LAS-ALB
# 159 af 800
# LAS-AMA
# 160 af 800
# LAS-AUS
# 161 af 800
# Not working for https://www.skyscanner.com/transport/flights/LAS/BDL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LAS-BDL
# 162 af 800
# LAS-BHM
# 163 af 800
# LAS-BNA
# 164 af 800
# LAS-BOI
# 165 af 800
# LAS-BUF
# 166 af 800
# LAS-BUR
# 167 af 800
# LAS-BWI
# 168 af 800
# LAS-CLE
# 169 af 800
# LAS-CMH
# 170 af 800
# LAS-DEN
# 171 af 800
# LAS-ELP
# 172 af 800
# LAS-GEG
# 173 af 800
# LAS-HOU
# 174 af 800
# LAS-IAD
# 175 af 800
# LAS-IND
# 176 af 800
# LAS-ISP
# 177 af 800
# LAS-LAX
# 178 af 800
# LAS-LBB
# 179 af 800
# LAS-LIT
# 180 af 800
# LAS-MAF
# 181 af 800
# LAS-MCI
# 182 af 800
# LAS-MCO
# 183 af 800
# LAS-MDW
# 184 af 800
# LAS-MHT
# 185 af 800
# LAS-MSY
# 186 af 800
# LAS-OAK
# 187 af 800
# LAS-OKC
# 188 af 800
# LAS-OMA
# 189 af 800
# LAS-ONT
# 190 af 800
# Not working for https://www.skyscanner.com/transport/flights/LAS/ORF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# LAS-ORF
# 191 af 800
# LAS-PDX
# 192 af 800
# LAS-PHL
# 193 af 800
# LAS-PHX
# 194 af 800
# LAS-PIT
# 195 af 800
# LAS-PVD
# 196 af 800
# LAS-RDU
# 197 af 800
# LAS-RNO
# 198 af 800
# LAS-SAN
# 199 af 800
# LAS-SAT
# 200 af 800
# LAS-SDF
# 201 af 800
# LAS-SEA
# 202 af 800
# LAS-SJC
# 203 af 800
# LAS-SLC
# 204 af 800
# LAS-SMF
# 205 af 800
# LAS-SNA
# 206 af 800
# LAS-STL
# 207 af 800
# LAS-TPA
# 208 af 800
# LAS-TUL
# 209 af 800
# LAS-TUS
# 210 af 800
# LAX-ABQ
# 211 af 800
# LAX-AUS
# 212 af 800
# LAX-BNA
# 213 af 800
# LAX-BWI
# 214 af 800
# LAX-ELP
# 215 af 800
# LAX-HOU
# 216 af 800
# LAX-LAS
# 217 af 800
# LAX-MCI
# 218 af 800
# LAX-MDW
# 219 af 800
# LAX-OAK
# 220 af 800
# LAX-PHL
# 221 af 800
# LAX-PHX
# 222 af 800
# LAX-RNO
# 223 af 800
# LAX-SAT
# 224 af 800
# LAX-SJC
# 225 af 800
# LAX-SLC
# 226 af 800
# LAX-SMF
# 227 af 800
# LAX-STL
# 228 af 800
# LAX-TUS
# 229 af 800
# LBB-ABQ
# 230 af 800
# LBB-AUS
# 231 af 800
# LBB-DAL
# 232 af 800
# LBB-ELP
# 233 af 800
# LBB-LAS
# 234 af 800
# LIT-BWI
# 235 af 800
# LIT-DAL
# 236 af 800
# LIT-HOU
# 237 af 800
# LIT-LAS
# 238 af 800
# LIT-MDW
# 239 af 800
# LIT-PHX
# 240 af 800
# LIT-STL
# 241 af 800
# MAF-ABQ
# 242 af 800
# MAF-AUS
# 243 af 800
# MAF-DAL
# 244 af 800
# MAF-ELP
# 245 af 800
# MAF-HOU
# 246 af 800
# MAF-LAS
# 247 af 800
# MCI-ABQ
# 248 af 800
# MCI-BNA
# 249 af 800
# MCI-BWI
# 250 af 800
# MCI-DAL
# 251 af 800
# MCI-DEN
# 252 af 800
# MCI-IND
# 253 af 800
# MCI-LAS
# 254 af 800
# MCI-LAX
# 255 af 800
# MCI-MCO
# 256 af 800
# MCI-MDW
# 257 af 800
# MCI-OAK
# 258 af 800
# Not working for https://www.skyscanner.com/transport/flights/MCI/OKC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCI-OKC
# 259 af 800
# MCI-PDX
# 260 af 800
# MCI-PHX
# 261 af 800
# MCI-SAN
# 262 af 800
# MCI-SEA
# 263 af 800
# MCI-SMF
# 264 af 800
# MCI-STL
# 265 af 800
# MCI-TPA
# 266 af 800
# MCI-TUL
# 267 af 800
# Not working for https://www.skyscanner.com/transport/flights/MCO/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MCO-ABQ
# 268 af 800
# MCO-ALB
# 269 af 800
# MCO-AUS
# 270 af 800
# MCO-BDL
# 271 af 800
# MCO-BHM
# 272 af 800
# MCO-BNA
# 273 af 800
# MCO-BUF
# 274 af 800
# MCO-BWI
# 275 af 800
# MCO-CMH
# 276 af 800
# MCO-DEN
# 277 af 800
# MCO-DTW
# 278 af 800
# MCO-FLL
# 279 af 800
# MCO-HOU
# 280 af 800
# MCO-IAD
# 281 af 800
# MCO-IND
# 282 af 800
# MCO-ISP
# 283 af 800
# MCO-JAN
# 284 af 800
# MCO-LAS
# 285 af 800
# MCO-MCI
# 286 af 800
# MCO-MDW
# 287 af 800
# MCO-MHT
# 288 af 800
# MCO-MSY
# 289 af 800
# MCO-ORF
# 290 af 800
# MCO-PHL
# 291 af 800
# MCO-PHX
# 292 af 800
# MCO-PIT
# 293 af 800
# MCO-PVD
# 294 af 800
# MCO-RDU
# 295 af 800
# MCO-RSW
# 296 af 800
# MCO-SAT
# 297 af 800
# MCO-SDF
# 298 af 800
# MCO-STL
# 299 af 800
# MDW-ABQ
# 300 af 800
# MDW-ALB
# 301 af 800
# MDW-AUS
# 302 af 800
# MDW-BDL
# 303 af 800
# MDW-BHM
# 304 af 800
# MDW-BNA
# 305 af 800
# MDW-BUF
# 306 af 800
# MDW-BWI
# 307 af 800
# MDW-CLE
# 308 af 800
# MDW-CMH
# 309 af 800
# MDW-DEN
# 310 af 800
# MDW-DTW
# 311 af 800
# MDW-FLL
# 312 af 800
# MDW-HOU
# 313 af 800
# MDW-IAD
# 314 af 800
# MDW-IND
# 315 af 800
# Not working for https://www.skyscanner.com/transport/flights/MDW/ISP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# MDW-ISP
# 316 af 800
# MDW-JAN
# 317 af 800
# MDW-LAS
# 318 af 800
# MDW-LAX
# 319 af 800
# MDW-LIT
# 320 af 800
# MDW-MCI
# 321 af 800
# MDW-MCO
# 322 af 800
# MDW-MHT
# 323 af 800
# MDW-MSY
# 324 af 800
# MDW-OAK
# 325 af 800
# MDW-OMA
# 326 af 800
# MDW-ORF
# 327 af 800
# MDW-PDX
# 328 af 800
# MDW-PHL
# 329 af 800
# MDW-PHX
# 330 af 800
# MDW-PIT
# 331 af 800
# MDW-PVD
# 332 af 800
# MDW-RDU
# 333 af 800
# MDW-RNO
# 334 af 800
# MDW-RSW
# 335 af 800
# MDW-SAN
# 336 af 800
# MDW-SAT
# 337 af 800
# MDW-SDF
# 338 af 800
# MDW-SEA
# 339 af 800
# MDW-SJC
# 340 af 800
# MDW-SLC
# 341 af 800
# MDW-SMF
# 342 af 800
# MDW-SNA
# 343 af 800
# MDW-STL
# 344 af 800
# MDW-TPA
# 345 af 800
# MDW-TUS
# 346 af 800
# MHT-BWI
# 347 af 800
# MHT-LAS
# 348 af 800
# MHT-MCO
# 349 af 800
# MHT-MDW
# 350 af 800
# MHT-PHL
# 351 af 800
# MHT-TPA
# 352 af 800
# MSY-BNA
# 353 af 800
# MSY-BWI
# 354 af 800
# MSY-DAL
# 355 af 800
# MSY-FLL
# 356 af 800
# MSY-HOU
# 357 af 800
# MSY-LAS
# 358 af 800
# MSY-MCO
# 359 af 800
# MSY-MDW
# 360 af 800
# MSY-PHX
# 361 af 800
# MSY-TPA
# 362 af 800
# OAK-ABQ
# 363 af 800
# OAK-BNA
# 364 af 800
# OAK-BOI
# 365 af 800
# OAK-BUR
# 366 af 800
# OAK-BWI
# 367 af 800
# OAK-GEG
# 368 af 800
# OAK-HOU
# 369 af 800
# OAK-LAS
# 370 af 800
# OAK-LAX
# 371 af 800
# OAK-MCI
# 372 af 800
# OAK-MDW
# 373 af 800
# OAK-ONT
# 374 af 800
# OAK-PDX
# 375 af 800
# Not working for https://www.skyscanner.com/transport/flights/OAK/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-PHL
# 376 af 800
# OAK-PHX
# 377 af 800
# OAK-RNO
# 378 af 800
# Not working for https://www.skyscanner.com/transport/flights/OAK/SAN/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SAN
# 379 af 800
# Not working for https://www.skyscanner.com/transport/flights/OAK/SEA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SEA
# 380 af 800
# Not working for https://www.skyscanner.com/transport/flights/OAK/SLC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SLC
# 381 af 800
# Not working for https://www.skyscanner.com/transport/flights/OAK/SNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OAK-SNA
# 382 af 800
# Not working for https://www.skyscanner.com/transport/flights/OKC/DAL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-DAL
# 383 af 800
# Not working for https://www.skyscanner.com/transport/flights/OKC/HOU/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-HOU
# 384 af 800
# Not working for https://www.skyscanner.com/transport/flights/OKC/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-LAS
# 385 af 800
# Not working for https://www.skyscanner.com/transport/flights/OKC/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-MCI
# 386 af 800
# Not working for https://www.skyscanner.com/transport/flights/OKC/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-PHX
# 387 af 800
# Not working for https://www.skyscanner.com/transport/flights/OKC/STL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OKC-STL
# 388 af 800
# Not working for https://www.skyscanner.com/transport/flights/OMA/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-LAS
# 389 af 800
# Not working for https://www.skyscanner.com/transport/flights/OMA/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-MDW
# 390 af 800
# Not working for https://www.skyscanner.com/transport/flights/OMA/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-PHX
# 391 af 800
# Not working for https://www.skyscanner.com/transport/flights/OMA/STL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# OMA-STL
# 392 af 800
# Not working for https://www.skyscanner.com/transport/flights/ONT/BNA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-BNA
# 393 af 800
# Not working for https://www.skyscanner.com/transport/flights/ONT/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-LAS
# 394 af 800
# Not working for https://www.skyscanner.com/transport/flights/ONT/OAK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-OAK
# 395 af 800
# Not working for https://www.skyscanner.com/transport/flights/ONT/PHX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-PHX
# 396 af 800
# Not working for https://www.skyscanner.com/transport/flights/ONT/SJC/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-SJC
# 397 af 800
# Not working for https://www.skyscanner.com/transport/flights/ONT/SMF/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ONT-SMF
# 398 af 800
# Not working for https://www.skyscanner.com/transport/flights/ORF/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-BWI
# 399 af 800
# Not working for https://www.skyscanner.com/transport/flights/ORF/JAX/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-JAX
# 400 af 800
# Not working for https://www.skyscanner.com/transport/flights/ORF/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-LAS
# 401 af 800
# Not working for https://www.skyscanner.com/transport/flights/ORF/MCO/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-MCO
# 402 af 800
# Not working for https://www.skyscanner.com/transport/flights/ORF/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# ORF-MDW
# 403 af 800
# Not working for https://www.skyscanner.com/transport/flights/PBI/BWI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-BWI
# 404 af 800
# Not working for https://www.skyscanner.com/transport/flights/PBI/ISP/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-ISP
# 405 af 800
# Not working for https://www.skyscanner.com/transport/flights/PBI/PHL/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-PHL
# 406 af 800
# Not working for https://www.skyscanner.com/transport/flights/PBI/TPA/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PBI-TPA
# 407 af 800
# Not working for https://www.skyscanner.com/transport/flights/PDX/ABQ/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-ABQ
# 408 af 800
# Not working for https://www.skyscanner.com/transport/flights/PDX/BOI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-BOI
# 409 af 800
# Not working for https://www.skyscanner.com/transport/flights/PDX/GEG/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-GEG
# 410 af 800
# Not working for https://www.skyscanner.com/transport/flights/PDX/LAS/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-LAS
# 411 af 800
# Not working for https://www.skyscanner.com/transport/flights/PDX/MCI/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-MCI
# 412 af 800
# Not working for https://www.skyscanner.com/transport/flights/PDX/MDW/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-MDW
# 413 af 800
# Not working for https://www.skyscanner.com/transport/flights/PDX/OAK/190527/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=true&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results
# PDX-OAK
# 414 af 800
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x118722fd0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-592-2b0b2b4542bf> in <module>
#       1 # Indsæt driverpath (skal vise lokal path)
#       2
# ----> 3 prices2=skyscannerscraper(data2['Origin'],data2['Dest'],190527,save='prices_200_1000', driverpath='/Users/Christian/Dropbox/Universitet/TSODAS/TSDS-gruppe-2019/Exam/geckodriver', direct='true')
#       4
#
# <ipython-input-591-25a2c6ca4c3b> in skyscannerscraper(dep, arr, date, save, driverpath, direct)
#      21         url = urlbase + str(depa) + str('/') + str(arri) + str('/')+ str(date) + urlpas + direct + urlend
#      22
# ---> 23         driver.get(url)
#      24         time.sleep(6)
#      25         try:
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     396
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#     400         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=49910): Max retries exceeded with url: /session/07ad80c1-0785-254c-b727-3306ddfb8090/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x118722fd0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %% [markdown]
# ### MORTEN

# %%
# Indsæt driverpath (skal vise lokal path)
prices2=skyscannerscraper(data6['Origin'],data6['Dest'],190527,save='prices_4000_', driverpath='', direct='true')

# %% [markdown]
# ### THOR

# %%
# Indsæt driverpath (skal vise lokal path)
prices2=skyscannerscraper(data5['Origin'],data5['Dest'],190527,save='prices_3000_3999', driverpath='', direct='true')

# %%
# Out:
#     alternative  day destination         label origin       price
# 0           NaN    0         LAX       Direkte    BWI   kr. 1.285
# 1         Ingen    0         LIT  1 omstigning    BWI   kr. 1.815
# 2                  0         MCI  1 omstigning    BWI   kr. 1.343
# 3           NaN    0         MCO       Direkte    BWI     kr. 428
# 4                  0         MDW  1 omstigning    BWI     kr. 838
# 5                  0         MHT  1 omstigning    BWI   kr. 1.102
# 6           NaN    0         MSY       Direkte    BWI     kr. 548
# 7                  0         OAK  1 omstigning    BWI   kr. 1.712
# 8           NaN    0         ORF             -    BWI           -
# 9                  0         PBI  1 omstigning    BWI     kr. 805
# 10          NaN    0         PHX       Direkte    BWI   kr. 1.663
# 11                 0         PVD  1 omstigning    BWI   kr. 1.975
# 12          NaN    0         RDU       Direkte    BWI     kr. 687
# 13                 0         RSW  1 omstigning    BWI     kr. 818
# 14          NaN    0         SAN       Direkte    BWI   kr. 1.333
# 15                 0         SAT  1 omstigning    BWI   kr. 1.623
# 16                 0         SDF  1 omstigning    BWI   kr. 1.125
# 17          NaN    0         SLC       Direkte    BWI   kr. 1.724
# 18                 0         STL  1 omstigning    BWI   kr. 1.417
# 19          NaN    0         TPA       Direkte    BWI     kr. 785
# 20                 0         BNA  1 omstigning    CLE     kr. 871
# 21          NaN    0         BWI             -    CLE           -
# 22          NaN    0         LAS       Direkte    CLE     kr. 554
# 23          NaN    0         MDW       Direkte    CLE  kr. 15.945
# 24                 0         PHX  1 omstigning    CLE   kr. 1.181
# 25                 0         STL  1 omstigning    CLE   kr. 1.004
# 26          NaN    0         BNA       Direkte    CMH  kr. 14.368
# 27                 0         BWI  1 omstigning    CMH   kr. 1.318
# 28          NaN    0         LAS       Direkte    CMH     kr. 840
# 29          NaN    0         MCO       Direkte    CMH     kr. 514
# ..          ...  ...         ...           ...    ...         ...
# 370         NaN    0         LAX       Direkte    OAK     kr. 716
# 371                0         MCI  1 omstigning    OAK     kr. 918
# 372                0         MDW  1 omstigning    OAK
# 373                0         ONT  1 omstigning    OAK   kr. 1.394
# 374         NaN    0         PDX       Direkte    OAK     kr. 818
# 375         NaN    0         PHL             -    OAK           -
# 376         NaN    0         PHX       Direkte    OAK   kr. 1.003
# 377         NaN    0         RNO       Direkte    OAK   kr. 9.839
# 378         NaN    0         SAN             -    OAK           -
# 379         NaN    0         SEA             -    OAK           -
# 380         NaN    0         SLC             -    OAK           -
# 381         NaN    0         SNA             -    OAK           -
# 382         NaN    0         DAL             -    OKC           -
# 383         NaN    0         HOU             -    OKC           -
# 384         NaN    0         LAS             -    OKC           -
# 385         NaN    0         MCI             -    OKC           -
# 386         NaN    0         PHX             -    OKC           -
# 387         NaN    0         STL             -    OKC           -
# 388         NaN    0         LAS             -    OMA           -
# 389         NaN    0         MDW             -    OMA           -
# 390         NaN    0         PHX             -    OMA           -
# 391         NaN    0         STL             -    OMA           -
# 392         NaN    0         BNA             -    ONT           -
# 393         NaN    0         LAS             -    ONT           -
# 394         NaN    0         OAK             -    ONT           -
# 395         NaN    0         PHX             -    ONT           -
# 396         NaN    0         SJC             -    ONT           -
# 397         NaN    0         SMF             -    ONT           -
# 398         NaN    0         BWI             -    ORF           -
# 399         NaN    0         JAX             -    ORF           -
#
# [400 rows x 6 columns]
